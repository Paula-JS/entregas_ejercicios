# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Read the csv

# %%
ruta = "/Users/paulajimenezsuaza/repos/trabajos_datascience/entregas_ejercicios/4-Fictional_Army/army.csv"
sep = ","
header = 0
index = 10

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.

# %%
df = pd.read_csv(ruta, sep = sep, header=header, index_col=index)
df
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Maine                4    Dragoons     1st      43        4  1592        73
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
# Louisana            10      Scouts     2nd      37        8  1099        63
# ...

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
#hecho arriba

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
df.loc[:, "veterans"]
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
df[["veterans", "deaths"]]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'regiment', 'company', 'deaths', 'battles', 'size',
#        'veterans', 'readiness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
resultado = df.loc[["Maine", "Alaska"],["deaths", "size", "deserters"]]
resultado
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
resultado9= df.iloc[3:7, 3:6]
resultado9
# Out:
#          deaths  battles  size
# origin
# Florida     616        2  1400
# Maine        43        4  1592
# Iowa        234        7  1006
# Alaska      523        8   987

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
resultado10 = df.iloc[4:, :]
resultado10
# Out:
#             Unnamed: 0  regiment company  deaths  battles  size  veterans  \
# origin
# Maine                4  Dragoons     1st      43        4  1592        73
# Iowa                 5  Dragoons     1st     234        7  1006        37
# Alaska               6  Dragoons     2nd     523        8   987       949
# Washington           7  Dragoons     2nd      62        3   849        48
# Oregon               8    Scouts     1st      62        4   973        48
# Wyoming              9    Scouts     1st      73        7  1005       435
# Louisana            10    Scouts     2nd      37        8  1099        63
# Georgia             11    Scouts     2nd      35        9  1523       345
#
#             readiness  armored  deserters
# origin
# Maine               2        0          3
# Iowa                1        1          4
# Alaska              2        0         24
# Washington          3        1         31
# Oregon              2        0          2
# ...

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
resultado11 = df.iloc[:4, :]
resultado11
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Texas               3        1         31
# Florida             3        1          2

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
resultado12 = df.iloc[:, 3:8]
resultado12
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        5  1045         1          1
# California      52       42   957         5          2
# Texas           25        2  1099        62          3
# Florida        616        2  1400        26          3
# Maine           43        4  1592        73          2
# Iowa           234        7  1006        37          1
# Alaska         523        8   987       949          2
# Washington      62        3   849        48          3
# Oregon          62        4   973        48          2
# Wyoming         73        7  1005       435          1
# Louisana        37        8  1099        63          2
# Georgia         35        9  1523       345          3

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
resultado13 = df.loc[:, "deaths"]>50
resultado13
# Out:
# origin
# Arizona        True
# California     True
# Texas         False
# Florida        True
# Maine         False
# Iowa           True
# Alaska         True
# Washington     True
# Oregon         True
# Wyoming        True
# Louisana      False
# Georgia       False
# Name: deaths, dtype: bool

# %%
mascara = df.loc[resultado13]
mascara
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Florida             3        1          2
# Iowa                1        1          4
# Alaska              2        0         24
# ...

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
resultado14 = (df.loc[: , "deaths"] >500) | (df.loc[: , "deaths"]<50)
resultado14
# Out:
# origin
# Arizona        True
# California    False
# Texas          True
# Florida        True
# Maine          True
# Iowa          False
# Alaska         True
# Washington    False
# Oregon        False
# Wyoming       False
# Louisana       True
# Georgia        True
# Name: deaths, dtype: bool

# %%
mascara = df.loc[resultado14]
mascara
# Out:
#           Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona            0  Nighthawks     1st     523        5  1045         1
# Texas              2  Nighthawks     2nd      25        2  1099        62
# Florida            3  Nighthawks     2nd     616        2  1400        26
# Maine              4    Dragoons     1st      43        4  1592        73
# Alaska             6    Dragoons     2nd     523        8   987       949
# Louisana          10      Scouts     2nd      37        8  1099        63
# Georgia           11      Scouts     2nd      35        9  1523       345
#
#           readiness  armored  deserters
# origin
# Arizona           1        1          4
# Texas             3        1         31
# Florida           3        1          2
# Maine             2        0          3
# Alaska            2        0         24
# Louisana          2        1          2
# Georgia           3        1          3

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
df
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Maine                4    Dragoons     1st      43        4  1592        73
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
# Louisana            10      Scouts     2nd      37        8  1099        63
# ...

# %%
resultado15 = df.loc[:, "regiment"]!= "Dragoons"
resultado15
# Out:
# origin
# Arizona        True
# California     True
# Texas          True
# Florida        True
# Maine         False
# Iowa          False
# Alaska        False
# Washington    False
# Oregon         True
# Wyoming        True
# Louisana       True
# Georgia        True
# Name: regiment, dtype: bool

# %%
mascara = df.loc[resultado15]
mascara
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
# Louisana            10      Scouts     2nd      37        8  1099        63
# Georgia             11      Scouts     2nd      35        9  1523       345
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Texas               3        1         31
# Florida             3        1          2
# Oregon              2        0          2
# ...

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
resultado16 = df.loc[["Texas", "Arizona"], : ]
resultado16
# Out:
#          Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Texas             2  Nighthawks     2nd      25        2  1099        62
# Arizona           0  Nighthawks     1st     523        5  1045         1
#
#          readiness  armored  deserters
# origin
# Texas            3        1         31
# Arizona          1        1          4

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
resultado17 = df.loc[["Arizona"] , ["deaths"]]
resultado17
# Out:
#          deaths
# origin
# Arizona     523

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
resultado18 = df.loc[["Oregon"], ["deaths"]]
resultado18
# Out:
#         deaths
# origin
# Oregon      62
