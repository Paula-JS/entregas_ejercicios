# %% [markdown]
# ### Ejercicio 1 - BBDD Restaurante
#
# 1. Mostrar todos los documentos de la colección restaurantes
# 2. Mostrar los campos restaurant_id, nombre, distrito y cocina, pero excluya el campo _id para todos los documentos de la colección restaurantes
# 3. Mostrar los primeros 5 restaurantes que se encuentran en el distrito Bronx
# 4. Devolver los restaurantes que lograron una puntuación superior a 80 pero inferior a 100
# 5. Devolver los restaurantes que se ubican en un valor de latitud inferior a -95.754168
# 6. Devolver los restaurantes que no preparan cocina americana y lograron una puntuación superior a 70 y se ubicaron en una longitud inferior a -65.754168. Nota: Realice esta consulta sin usar el operador $and
# 7. Devolver los restaurantes que no preparan cocina americana y lograron un punto de calificación 'A' que no pertenece al distrito de Brooklyn. El documento debe mostrarse según la cocina en orden descendente.
# 8. Devolver los restaurantes que pertenecen al distrito Bronx y preparan platos americanos o chinos
# 9. Devolver ID del restaurante, nombre, distrito y la cocina para aquellos restaurantes que pertenecen al distrito de Staten Island o Queens o Bronx o Brooklyn
# 10. Devolver ID del restaurante, nombre, distrito y la cocina de aquellos restaurantes que lograron una puntuación que no supere los 10
# 11. Devolver ID del restaurante, el nombre y las calificaciones del restaurante para aquellos restaurantes que obtuvieron una calificación de "A" y obtuvieron un puntaje de 11 en una fecha ISO "2014-08-11T00: 00: 00Z" entre muchas fechas de encuesta
# 12. Devolver ID del restaurante, nombre, dirección y ubicación geográfica del restaurante de aquellos donde el segundo elemento de la matriz coord contiene un valor que es más de 42 y hasta 52

# %%
import pymongo
import json

# %%
# url = 'mongodb+srv://admin:admin@cluster0.xmr3d6s.mongodb.net/?retryWrites=true&w=majority'

# %%
url = "mongodb+srv://admin:admin@cluster0.jpwo6w9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
#with open('restaurants.json','r') as r:
    #data = json.load(r)


# url = f'{connection_type}+{user}+':'+{password}+{adress}+{resto}
#myclient = pymongo.MongoClient(url)

#mydb = myclient["Cluster0"] # INSTANCIAR BASE DE DATOS
#restaurantes = mydb['restaurantes']
#restaurantes.insert_many(data)
# Out:
# InsertManyResult([ObjectId('67349921fbc7c3b08a31af68'), ObjectId('67349921fbc7c3b08a31af69'), ObjectId('67349921fbc7c3b08a31af6a'), ObjectId('67349921fbc7c3b08a31af6b'), ObjectId('67349921fbc7c3b08a31af6c'), ObjectId('67349921fbc7c3b08a31af6d'), ObjectId('67349921fbc7c3b08a31af6e'), ObjectId('67349921fbc7c3b08a31af6f'), ObjectId('67349921fbc7c3b08a31af70'), ObjectId('67349921fbc7c3b08a31af71'), ObjectId('67349921fbc7c3b08a31af72'), ObjectId('67349921fbc7c3b08a31af73'), ObjectId('67349921fbc7c3b08a31af74'), ObjectId('67349921fbc7c3b08a31af75'), ObjectId('67349921fbc7c3b08a31af76'), ObjectId('67349921fbc7c3b08a31af77'), ObjectId('67349921fbc7c3b08a31af78'), ObjectId('67349921fbc7c3b08a31af79'), ObjectId('67349921fbc7c3b08a31af7a'), ObjectId('67349921fbc7c3b08a31af7b'), ObjectId('67349921fbc7c3b08a31af7c'), ObjectId('67349921fbc7c3b08a31af7d'), ObjectId('67349921fbc7c3b08a31af7e'), ObjectId('67349921fbc7c3b08a31af7f'), ObjectId('67349921fbc7c3b08a31af80'), ObjectId('67349921fbc7c3b08a31af81'), ObjectId('67349921fbc7c3b08a31af82'), ObjectId('67349921fbc7c3b08a31af83'), ObjectId('67349921fbc7c3b08a31af84'), ObjectId('67349921fbc7c3b08a31af85'), ObjectId('67349921fbc7c3b08a31af86'), ObjectId('67349921fbc7c3b08a31af87'), ObjectId('67349921fbc7c3b08a31af88'), ObjectId('67349921fbc7c3b08a31af89'), ObjectId('67349921fbc7c3b08a31af8a'), ObjectId('67349921fbc7c3b08a31af8b'), ObjectId('67349921fbc7c3b08a31af8c'), ObjectId('67349921fbc7c3b08a31af8d'), ObjectId('67349921fbc7c3b08a31af8e'), ObjectId('67349921fbc7c3b08a31af8f'), ObjectId('67349921fbc7c3b08a31af90'), ObjectId('67349921fbc7c3b08a31af91'), ObjectId('67349921fbc7c3b08a31af92'), ObjectId('67349921fbc7c3b08a31af93'), ObjectId('67349921fbc7c3b08a31af94'), ObjectId('67349921fbc7c3b08a31af95'), ObjectId('67349921fbc7c3b08a31af96'), ObjectId('67349921fbc7c3b08a31af97'), ObjectId('67349921fbc7c3b08a31af98'), ObjectId('67349921fbc7c3b08a31af99'), ObjectId('67349921fbc7c3b08a31af9a'), ObjectId('67349921fbc7c3b08a31af9b'), ObjectId('67349921fbc7c3b08a31af9c'), ObjectId('67349921fbc7c3b08a31af9d'), ObjectId('67349921fbc7c3b08a31af9e'), ObjectId('67349921fbc7c3b08a31af9f'), ObjectId('67349921fbc7c3b08a31afa0'), ObjectId('67349921fbc7c3b08a31afa1'), ObjectId('67349921fbc7c3b08a31afa2'), ObjectId('67349921fbc7c3b08a31afa3'), ObjectId('67349921fbc7c3b08a31afa4'), ObjectId('67349921fbc7c3b08a31afa5'), ObjectId('67349921fbc7c3b08a31afa6'), ObjectId('67349921fbc7c3b08a31afa7'), ObjectId('67349921fbc7c3b08a31afa8'), ObjectId('67349921fbc7c3b08a31afa9'), ObjectId('67349921fbc7c3b08a31afaa'), ObjectId('67349921fbc7c3b08a31afab'), ObjectId('67349921fbc7c3b08a31afac'), ObjectId('67349921fbc7c3b08a31afad'), ObjectId('67349921fbc7c3b08a31afae'), ObjectId('67349921fbc7c3b08a31afaf'), ObjectId('67349921fbc7c3b08a31afb0'), ObjectId('67349921fbc7c3b08a31afb1'), ObjectId('67349921fbc7c3b08a31afb2'), ObjectId('67349921fbc7c3b08a31afb3'), ObjectId('67349921fbc7c3b08a31afb4'), ObjectId('67349921fbc7c3b08a31afb5'), ObjectId('67349921fbc7c3b08a31afb6'), ObjectId('67349921fbc7c3b08a31afb7'), ObjectId('67349921fbc7c3b08a31afb8'), ObjectId('67349921fbc7c3b08a31afb9'), ObjectId('67349921fbc7c3b08a31afba'), ObjectId('67349921fbc7c3b08a31afbb'), ObjectId('67349921fbc7c3b08a31afbc'), ObjectId('67349921fbc7c3b08a31afbd'), ObjectId('67349921fbc7c3b08a31afbe'), ObjectId('67349921fbc7c3b08a31afbf'), ObjectId('67349921fbc7c3b08a31afc0'), ObjectId('67349921fbc7c3b08a31afc1'), ObjectId('67349921fbc7c3b08a31afc2'), ObjectId('67349921fbc7c3b08a31afc3'), ObjectId('67349921fbc7c3b08a31afc4'), ObjectId('67349921fbc7c3b08a31afc5'), ObjectId('67349921fbc7c3b08a31afc6'), ObjectId('67349921fbc7c3b08a31afc7'), ObjectId('67349921fbc7c3b08a31afc8'), ObjectId('67349921fbc7c3b08a31afc9'), ObjectId('67349921fbc7c3b08a31afca'), ObjectId('67349921fbc7c3b08a31afcb'), ObjectId('67349921fbc7c3b08a31afcc'), ObjectId('67349921fbc7c3b08a31afcd'), ObjectId('67349921fbc7c3b08a31afce'), ObjectId('67349921fbc7c3b08a31afcf'), ObjectId('67349921fbc7c3b08a31 ...

# %%
url = "mongodb+srv://admin:admin@cluster0.jpwo6w9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
myclient = pymongo.MongoClient(url)
mydb = myclient["Cluster0"] # INSTANCIAR BASE DE DATOS
restaurantes = mydb['restaurantes']

# %% [markdown]
# ### 1. Mostrar todos los documentos de la colección restaurantes

# %%
filtro = {}
proyeccion = {"_id":0}
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'address': {'building': '1007',
#    'coord': [-73.856077, 40.848447],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'address': {'building': '469',
#    'coord': [-73.961704, 40.662942],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11225'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1404172800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1336435200000}, 'grade': 'A', 'score': 12}],
#   'name': "Wendy'S",
#   'restaurant_id': '30112340'},
#  {'address': {'building': '351',
#    'coord': [-73.98513559999999, 40.7676919],
#    'street': 'West   57 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1374451200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343692800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1325116800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Dj Reynolds Pub And Restaurant',
#   'restaurant_id': '30191841'},
#  {'address': {'building': '2780',
#    'coord': [-73.98241999999999, 40.579505],
#    'street': 'Stillwell Avenue',
#    'zipcode': '11224'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1370390400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1318377600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Riviera Caterer',
#   'restaurant_id': '40356018'},
#  {'address': {'building': '97-22',
#    'coord': [-73.8601152, 40.7311739],
#    'street': '63 Road',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1416787200000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1358380800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1343865600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1323907200000}, 'grade': 'B', 'score': 25}],
#   'name': 'Tov Kosher Kitchen',
#   'restaurant_id': '40356068'},
#  {'address': {'building': '8825',
#    'coord': [-73.8803827, 40.7643124],
#    'street': 'Astoria Boulevard',
#    'zipcode': '11369'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1416009600000}, 'grade': 'Z', 'score': 38},
#    {'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1362182400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1328832000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Brunos On The Boulevard',
#   'restaurant_id': '40356151'},
#  {'address': {'building': '2206',
#    'coord': [-74.1377286, 40.6119572],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1412553600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400544000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1365033600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1327363200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Kosher Island',
#   'restaurant_id': '40356442'},
#  {'address': {'building': '7114',
#    'coord': [-73.9068506, 40.6199034],
#    'street': 'Avenue U',
#    'zipcode': '11234'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1401321600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1375488000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1342569600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1331251200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318550400000}, 'grade': 'A', 'score': 9}],
#   'name': "Wilken'S Fine Food",
#   'restaurant_id': '40356483'},
#  {'address': {'building': '6409',
#    'coord': [-74.00528899999999, 40.628886],
#    'street': '11 Avenue',
#    'zipcode': '11219'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405641600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1375142400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1360713600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1345075200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Regina Caterers',
#   'restaurant_id': '40356649'},
#  {'address': {'building': '1839',
#    'coord': [-73.9482609, 40.6408271],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11226'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1405296000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1373414400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1341964800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1329955200000}, 'grade': 'A', 'score': 8}],
#   'name': 'Taste The Tropics Ice Cream',
#   'restaurant_id': '40356731'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401235200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1339718400000}, 'grade': 'A', 'score': 3}],
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'address': {'building': '7715',
#    'coord': [-73.9973325, 40.61174889999999],
#    'street': '18 Avenue',
#    'zipcode': '11214'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1397606400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1366675200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1335225600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1323993600000}, 'grade': 'A', 'score': 2}],
#   'name': 'C & C Catering Service',
#   'restaurant_id': '40357437'},
#  {'address': {'building': '1269',
#    'coord': [-73.871194, 40.6730975],
#    'street': 'Sutter Avenue',
#    'zipcode': '11208'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1410825600000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1377648000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1364860800000}, 'grade': 'C', 'score': 56},
#    {'date': {'$date': 1344988800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1332892800000}, 'grade': 'B', 'score': 27}],
#   'name': 'May May Kitchen',
#   'restaurant_id': '40358429'},
#  {'address': {'building': '1',
#    'coord': [-73.96926909999999, 40.7685235],
#    'street': 'East   66 Street',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1399420800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1367539200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1324944000000}, 'grade': 'A', 'score': 0}],
#   'name': '1 East 66Th Street Kitchen',
#   'restaurant_id': '40359480'},
#  {'address': {'building': '705',
#    'coord': [-73.9653967, 40.6064339],
#    'street': 'Kings Highway',
#    'zipcode': '11223'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1415577600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1349308800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1337558400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1325203200000}, 'grade': 'B', 'score': 19}],
#   'name': 'Seuda Foods',
#   'restaurant_id': '40360045'},
#  {'address': {'building': '203',
#    'coord': [-73.97822040000001, 40.6435254],
#    'street': 'Church Avenue',
#    'zipcode': '11218'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1391990400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1357084800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1326067200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1320624000000}, 'grade': 'P', 'score': 12},
#    {'date': {'$date': 1311206400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40360076'},
#  {'address': {'building': '265-15',
#    'coord': [-73.7032601, 40.7386417],
#    'street': 'Hillside Avenue',
#    'zipcode': '11004'},
#   'borough': 'Queens',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1414454400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40361322'},
#  {'address': {'building': '6909',
#    'coord': [-74.0259567, 40.6353674],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1408579200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1393977600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1357776000000}, 'grade': 'A', 'score': 10}],
#   'name': 'Nordic Delicacies',
#   'restaurant_id': '40361390'},
#  {'address': {'building': '522',
#    'coord': [-73.95171, 40.767461],
#    'street': 'East   74 Street',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1409616000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1387411200000}, 'grade': 'B', 'score': 16},
#    {'date': {'$date': 1369699200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1354838400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1332979200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Glorious Food',
#   'restaurant_id': '40361521'},
#  {'address': {'building': '284',
#    'coord': [-73.9829239, 40.6580753],
#    'street': 'Prospect Park West',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1416355200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1384387200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1354665600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1337212800000}, 'grade': 'A', 'score': 11}],
#   'name': 'The Movable Feast',
#   'restaurant_id': '40361606'},
#  {'address': {'building': '129-08',
#    'coord': [-73.839297, 40.78147],
#    'street': '20 Avenue',
#    'zipcode': '11356'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1408147200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1377561600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1317254400000}, 'grade': 'A', 'score': 10}],
#   'name': "Sal'S Deli",
#   'restaurant_id': '40361618'},
#  {'address': {'building': '759',
#    'coord': [-73.9925306, 40.7309346],
#    'street': 'Broadway',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1390262400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1357257600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1339027200000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 8}],
#   'name': "Bully'S Deli",
#   'restaurant_id': '40361708'},
#  {'address': {'building': '3406',
#    'coord': [-73.94024739999999, 40.7623288],
#    'street': '10 Street',
#    'zipcode': '11106'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1395187200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1363132800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1332806400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1301961600000}, 'grade': 'A', 'score': 7}],
#   'name': "Steve Chu'S Deli & Grocery",
#   'restaurant_id': '40361998'},
#  {'address': {'building': '502',
#    'coord': [-73.976112, 40.786714],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1393891200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1374105600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1357689600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1334016000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1321315200000}, 'grade': 'A', 'score': 7}],
#   'name': "Harriet'S Kitchen",
#   'restaurant_id': '40362098'},
#  {'address': {'building': '730',
#    'coord': [-73.96805719999999, 40.7925587],
#    'street': 'Columbus Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1410480000000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1377648000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1364169600000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1329177600000}, 'grade': 'A', 'score': 12}],
#   'name': 'P & S Deli Grocery',
#   'restaurant_id': '40362264'},
#  {'address': {'building': '18',
#    'coord': [-73.996984, 40.72589],
#    'street': 'West Houston Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1365120000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1332288000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1303862400000}, 'grade': 'A', 'score': 5}],
#   'name': 'Angelika Film Center',
#   'restaurant_id': '40362274'},
#  {'address': {'building': '531',
#    'coord': [-73.9634876, 40.6940001],
#    'street': 'Myrtle Avenue',
#    'zipcode': '11205'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1395100800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1363564800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1349827200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1316649600000}, 'grade': 'A', 'score': 2}],
#   'name': 'White Castle',
#   'restaurant_id': '40362344'},
#  {'address': {'building': '103-05',
#    'coord': [-73.8642349, 40.75356],
#    'street': '37 Avenue',
#    'zipcode': '11368'},
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1398038400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1384214400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1370304000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1352851200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1349913600000}, 'grade': 'P', 'score': 0},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1323302400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1311120000000}, 'grade': 'A', 'score': 11}],
#   'name': 'Ho Mei Restaurant',
#   'restaurant_id': '40362432'},
#  {'address': {'building': '60',
#    'coord': [-74.0085357, 40.70620539999999],
#    'street': 'Wall Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'date': {'$date': 1411689600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1348185600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336521600000}, 'grade': 'A', 'score': 11}],
#   'name': 'The Country Cafe',
#   'restaurant_id': '40362715'},
#  {'address': {'building': '195',
#    'coord': [-73.9246028, 40.6522396],
#    'street': 'East   56 Street',
#    'zipcode': '11203'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'grades': [{'date': {'$date': 1399939200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1367971200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1348272000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1307318400000}, 'grade': 'A', 'score': 12}],
#   'name': "Shashemene Int'L Restaura",
#   'restaurant_id': '40362869'},
#  {'address': {'building': '107',
#    'coord': [-74.00920839999999, 40.7132925],
#    'street': 'Church Street',
#    'zipcode': '10007'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405641600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1393372800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1377475200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1359676800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318896000000}, 'grade': 'A', 'score': 11}],
#   'name': 'Downtown Deli',
#   'restaurant_id': '40363021'},
#  {'address': {'building': '1006',
#    'coord': [-73.84856870000002, 40.8903781],
#    'street': 'East 233 Street',
#    'zipcode': '10466'},
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1378339200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1361404800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1341273600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1310342400000}, 'grade': 'A', 'score': 5}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'address': {'building': '56',
#    'coord': [-73.991495, 40.692273],
#    'street': 'Court Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1389744000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 10}],
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40363098'},
#  {'address': {'building': '7615',
#    'coord': [-74.0228449, 40.6281815],
#    'street': '5 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1417651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1382572800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1366243200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1333584000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Mejlander & Mulgannon',
#   'restaurant_id': '40363117'},
#  {'address': {'building': '120',
#    'coord': [-73.9998042, 40.7251256],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1413504000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1324252800000}, 'grade': 'A', 'score': 3}],
#   'name': "Olive'S",
#   'restaurant_id': '40363151'},
#  {'address': {'building': '1236',
#    'coord': [-73.8893654, 40.81376179999999],
#    'street': '238 Spofford Ave',
#    'zipcode': '10474'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1388361600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1339459200000}, 'grade': 'B', 'score': 15}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'address': {'building': '625',
#    'coord': [-73.990494, 40.7569545],
#    'street': '8 Avenue',
#    'zipcode': '10018'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402272000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1389312000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1354838400000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1323734400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1315526400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Cafe Metro',
#   'restaurant_id': '40363298'},
#  {'address': {'building': '1069',
#    'coord': [-73.902463, 40.694924],
#    'street': 'Wyckoff Avenue',
#    'zipcode': '11385'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1399507200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1371772800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1356307200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1308096000000}, 'grade': 'A', 'score': 10}],
#   'name': "Tony'S Deli",
#   'restaurant_id': '40363333'},
#  {'address': {'building': '405',
#    'coord': [-73.97534999999999, 40.7516269],
#    'street': 'Lexington Avenue',
#    'zipcode': '10174'},
#   'borough': 'Manhattan',
#   'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#   'grades': [{'date': {'$date': 1392940800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1379030400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346112000000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1315872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1304380800000}, 'grade': 'A', 'score': 5}],
#   'name': 'Lexler Deli',
#   'restaurant_id': '40363426'},
#  {'address': {'building': '2491',
#    'coord': [-74.1459332, 40.6103714],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1420761600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1386201600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bagels N Buns',
#   'restaurant_id': '40363427'},
#  {'address': {'building': '7905',
#    'coord': [-73.8740217, 40.7135015],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'borough': 'Queens',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'date': {'$date': 1410912000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389830400000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1375833600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1361404800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1340150400000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1327968000000}, 'grade': 'B', 'score': 18}],
#   'name': 'Hot Bagels',
#   'restaurant_id': '40363565'},
#  {'address': {'building': '87-69',
#    'coord': [-73.8309503, 40.7001121],
#    'street': 'Lefferts Boulevard',
#    'zipcode': '11418'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1393286400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1376438400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1344297600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1332720000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1320364800000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1309305600000}, 'grade': 'A', 'score': 4}],
#   'name': 'Snack Time Grill',
#   'restaurant_id': '40363590'},
#  {'address': {'building': '1418',
#    'coord': [-73.95685019999999, 40.7753401],
#    'street': 'Third Avenue',
#    'zipcode': '10028'},
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'date': {'$date': 1401667200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1388102400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1363564800000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1328054400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1309910400000}, 'grade': 'B', 'score': 25}],
#   'name': "Lorenzo & Maria'S",
#   'restaurant_id': '40363630'},
#  {'address': {'building': '464',
#    'coord': [-73.9791458, 40.744328],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1407196800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1394064000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1373328000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1359504000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1325721600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1316995200000}, 'grade': 'A', 'score': 0}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363644'},
#  {'address': {'building': '437',
#    'coord': [-73.975393, 40.757365],
#    'street': 'Madison Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401753600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370563200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1340928000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1328486400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1308787200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Berkely',
#   'restaurant_id': '40363685'},
#  {'address': {'building': '1031',
#    'coord': [-73.9075537, 40.6438684],
#    'street': 'East   92 Street',
#    'zipcode': '11236'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1391558400000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1359417600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1323302400000}, 'grade': 'A', 'score': 10}],
#   'name': "Sonny'S Heros",
#   'restaurant_id': '40363744'},
#  {'address': {'building': '1111',
#    'coord': [-74.0796436, 40.59878339999999],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10305'},
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1328140800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363834'},
#  {'address': {'building': '976',
#    'coord': [-73.92701509999999, 40.6620192],
#    'street': 'Rutland Road',
#    'zipcode': '11212'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1398211200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1331596800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1321401600000}, 'grade': 'A', 'score': 13}],
#   'name': 'Golden Pavillion',
#   'restaurant_id': '40363920'},
#  {'address': {'building': '148',
#    'coord': [-73.9806854, 40.7778589],
#    'street': 'West   72 Street',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1417996800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1399248000000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1365120000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1333065600000}, 'grade': 'A', 'score': 9}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363945'},
#  {'address': {'building': '364',
#    'coord': [-73.96084119999999, 40.8014307],
#    'street': 'West  110 Street',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1409788800000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1393372800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1364169600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1329782400000}, 'grade': 'A', 'score': 8}],
#   'name': 'Spoon Bread Catering',
#   'restaurant_id': '40364179'},
#  {'address': {'building': '1423',
#    'coord': [-73.9615132, 40.6253268],
#    'street': 'Avenue J',
#    'zipcode': '11230'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1418947200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1386201600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 9}],
#   'name': 'Kosher Bagel Hole',
#   'restaurant_id': '40364220'},
#  {'address': {'building': '0',
#    'coord': [-84.2040813, 9.9986585],
#    'street': 'Guardia Airport Parking',
#    'zipcode': '11371'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400198400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1337040000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1320192000000}, 'grade': 'C', 'score': 32}],
#   'name': 'Terminal Cafe/Yankee Clipper',
#   'restaurant_id': '40364262'},
#  {'address': {'building': '73',
#    'coord': [-74.1178949, 40.5734906],
#    'street': 'New Dorp Plaza',
#    'zipcode': '10306'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1416268800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1383782400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1332201600000}, 'grade': 'A', 'score': 5}],
#   'name': 'Plaza Bagels & Deli',
#   'restaurant_id': '40364286'},
#  {'address': {'building': '277',
#    'coord': [-73.8941893, 40.8634684],
#    'street': 'East Kingsbridge Road',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1363651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'address': {'building': '203',
#    'coord': [-74.15235919999999, 40.5563756],
#    'street': 'Giffords Lane',
#    'zipcode': '10308'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1420416000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1410393600000}, 'grade': 'C', 'score': 39},
#    {'date': {'$date': 1395273600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1337731200000}, 'grade': 'A', 'score': 10}],
#   'name': 'B & M Hot Bagel & Grocery',
#   'restaurant_id': '40364299'},
#  {'address': {'building': '94',
#    'coord': [-74.0061936, 40.7092038],
#    'street': 'Fulton Street',
#    'zipcode': '10038'},
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1420502400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1405382400000}, 'grade': 'C', 'score': 48},
#    {'date': {'$date': 1367452800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1348444800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1334793600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Texas Rotisserie',
#   'restaurant_id': '40364304'},
#  {'address': {'building': '10004',
#    'coord': [-74.03400479999999, 40.6127077],
#    'street': '4 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1393286400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1372291200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1354492800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1320796800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Philadelhia Grille Express',
#   'restaurant_id': '40364305'},
#  {'address': {'building': '178',
#    'coord': [-73.96252129999999, 40.7098035],
#    'street': 'Broadway',
#    'zipcode': '11211'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'date': {'$date': 1394236800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1380326400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1347235200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1313366400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Peter Luger Steakhouse',
#   'restaurant_id': '40364335'},
#  {'address': {'building': '1',
#    'coord': [-73.97166039999999, 40.764832],
#    'street': 'East   60 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1413417600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1364860800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1350604800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1335484800000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1322524800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Metropolitan Club',
#   'restaurant_id': '40364347'},
#  {'address': {'building': '837',
#    'coord': [-73.9712, 40.751703],
#    'street': '2 Avenue',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405987200000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1317772800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Palm Restaurant',
#   'restaurant_id': '40364355'},
#  {'address': {'building': '21',
#    'coord': [-73.9774394, 40.7604522],
#    'street': 'West   52 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400025600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1376352000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1333497600000}, 'grade': 'A', 'score': 12}],
#   'name': '21 Club',
#   'restaurant_id': '40364362'},
#  {'address': {'building': '658',
#    'coord': [-73.81363999999999, 40.82941100000001],
#    'street': 'Clarence Ave',
#    'zipcode': '10465'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1403308800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1341964800000}, 'grade': 'A', 'score': 10}],
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'address': {'building': '1028',
#    'coord': [-73.966032, 40.762832],
#    'street': '3 Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1410825600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1393200000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1367539200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1345420800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1329091200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Isle Of Capri Resturant',
#   'restaurant_id': '40364373'},
#  {'address': {'building': '45',
#    'coord': [-73.9891878, 40.7375638],
#    'street': 'East   18 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1412726400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1366761600000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1326067200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Old Town Bar & Restaurant',
#   'restaurant_id': '40364389'},
#  {'address': {'building': '261',
#    'coord': [-73.94839189999999, 40.7224876],
#    'street': 'Driggs Avenue',
#    'zipcode': '11222'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'grades': [{'date': {'$date': 1401494400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1329436800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1318550400000}, 'grade': 'C', 'score': 54}],
#   'name': 'Polish National Home',
#   'restaurant_id': '40364404'},
#  {'address': {'building': '62',
#    'coord': [-74.00310999999999, 40.7348888],
#    'street': 'Charles Street',
#    'zipcode': '10014'},
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1369008000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1326844800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1317600000000}, 'grade': 'A', 'score': 10}],
#   'name': 'Seville Restaurant',
#   'restaurant_id': '40364439'},
#  {'address': {'building': '100',
#    'coord': [-74.0010484, 40.71599000000001],
#    'street': 'Centre Street',
#    'zipcode': '10013'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1362700800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1331251200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1301529600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Criminal Court Bldg Cafeteria',
#   'restaurant_id': '40364443'},
#  {'address': {'building': '657',
#    'coord': [-73.9056678, 40.7066898],
#    'street': 'Fairview Avenue',
#    'zipcode': '11385'},
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'grades': [{'date': {'$date': 1394841600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1363046400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1342828800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1322179200000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1308700800000}, 'grade': 'B', 'score': 20}],
#   'name': 'Gottscheer Hall',
#   'restaurant_id': '40364449'},
#  {'address': {'building': '180',
#    'coord': [-73.9788694, 40.7665961],
#    'street': 'Central Park South',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418601600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1407369600000}, 'grade': 'C', 'score': 40},
#    {'date': {'$date': 1375056000000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1355356800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343606400000}, 'grade': 'C', 'score': 4},
#    {'date': {'$date': 1329350400000}, 'grade': 'A', 'score': 2}],
#   'name': 'Nyac Main Dining Room',
#   'restaurant_id': '40364467'},
#  {'address': {'building': '108',
#    'coord': [-73.98146, 40.7250067],
#    'street': 'Avenue B',
#    'zipcode': '10009'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405296000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1388448000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1350864000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1336348800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318550400000}, 'grade': 'A', 'score': 12}],
#   'name': '7B Bar',
#   'restaurant_id': '40364518'},
#  {'address': {'building': '96-40',
#    'coord': [-73.86137149999999, 40.7293762],
#    'street': 'Queens Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1394668800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1380499200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1366934400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1347321600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1316390400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1300320000000}, 'grade': 'A', 'score': 12}],
#   'name': 'Ben-Best Deli & Restaurant',
#   'restaurant_id': '40364529'},
#  {'address': {'building': '215',
#    'coord': [-73.9805679, 40.7659436],
#    'street': 'West 57 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1411603200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1392336000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1376006400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1361491200000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1329350400000}, 'grade': 'A', 'score': 8}],
#   'name': 'Cafe Atelier (Art Students League)',
#   'restaurant_id': '40364531'},
#  {'address': {'building': '845',
#    'coord': [-73.965531, 40.765431],
#    'street': 'Lexington Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1363824000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1350518400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336348800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1305590400000}, 'grade': 'A', 'score': 5}],
#   'name': "Donohue'S Steak House",
#   'restaurant_id': '40364572'},
#  {'address': {'building': '311',
#    'coord': [-73.98621899999999, 40.763406],
#    'street': 'West   51 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1415577600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1374019200000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1360108800000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1342396800000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1331164800000}, 'grade': 'C', 'score': 7}],
#   'name': 'Tout Va Bien',
#   'restaurant_id': '40364576'},
#  {'address': {'building': '386',
#    'coord': [-73.9818918, 40.6901211],
#    'street': 'Flatbush Avenue Extension',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1415923200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1394409600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1357776000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346716800000}, 'grade': 'A', 'score': 7}],
#   'name': "Junior'S",
#   'restaurant_id': '40364581'},
#  {'address': {'building': '37',
#    'coord': [-74.138263, 40.546681],
#    'street': 'Mansion Ave',
#    'zipcode': '10308'},
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1398124800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1339200000000}, 'grade': 'A', 'score': 8}],
#   'name': 'Great Kills Yacht Club',
#   'restaurant_id': '40364610'},
#  {'address': {'building': '251',
#    'coord': [-73.9775552, 40.7432016],
#    'street': 'East   31 Street',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1398124800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1371600000000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1337644800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Marchis Restaurant',
#   'restaurant_id': '40364668'},
#  {'address': {'building': '2602',
#    'coord': [-73.95443709999999, 40.5877993],
#    'street': 'East   15 Street',
#    'zipcode': '11235'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400025600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1367020800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1353628800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1331683200000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1310601600000}, 'grade': 'B', 'score': 21}],
#   'name': 'Towne Cafe',
#   'restaurant_id': '40364681'},
#  {'address': {'building': '.1-A',
#    'coord': [-48.9424, -16.3550032],
#    'street': 'East 77 St',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'date': {'$date': 1416787200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1364947200000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1349136000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1335312000000}, 'grade': 'A', 'score': 8}],
#   'name': 'Dining Room',
#   'restaurant_id': '40364691'},
#  {'address': {'building': '56',
#    'coord': [-74.004758, 40.741207],
#    'street': '9 Avenue',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370822400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1348617600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1321228800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Old Homestead',
#   'restaurant_id': '40364715'},
#  {'address': {'building': '156-71',
#    'coord': [-73.840437, 40.6627235],
#    'street': 'Crossbay Boulevard',
#    'zipcode': '11414'},
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1414540800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1383091200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370995200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1332806400000}, 'grade': 'A', 'score': 9}],
#   'name': 'New Park Pizzeria & Restaurant',
#   'restaurant_id': '40364744'},
#  {'address': {'building': '600',
#    'coord': [-73.7522366, 40.7766941],
#    'street': 'West Drive',
#    'zipcode': '11363'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1386115200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1371081600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1334188800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1311984000000}, 'grade': 'B', 'score': 23}],
#   'name': 'Douglaston Club',
#   'restaurant_id': '40364858'},
#  {'address': {'building': '225',
#    'coord': [-73.96485799999999, 40.761899],
#    'street': 'East   60 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1407715200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1394755200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1358294400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1342051200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Serendipity 3',
#   'restaurant_id': '40364863'},
#  {'address': {'building': '461',
#    'coord': [-74.002944, 40.652779],
#    'street': '37 Street',
#    'zipcode': '11232'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1417132800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1386115200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1323129600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Melody Lanes',
#   'restaurant_id': '40364889'},
#  {'address': {'building': '30-13',
#    'coord': [-73.9151096, 40.763377],
#    'street': 'Steinway Street',
#    'zipcode': '11103'},
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1412553600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1351036800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1339545600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 10}],
#   'name': "Rizzo'S Fine Pizza",
#   'restaurant_id': '40364920'},
#  {'address': {'building': '2222',
#    'coord': [-73.84971759999999, 40.8304811],
#    'street': 'Haviland Avenue',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418860800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1398902400000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1363219200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1328659200000}, 'grade': 'B', 'score': 19}],
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'address': {'building': '567',
#    'coord': [-74.00619499999999, 40.735663],
#    'street': 'Hudson Street',
#    'zipcode': '10014'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1406505600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1374710400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1360022400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1338249600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1324598400000}, 'grade': 'A', 'score': 5}],
#   'name': 'White Horse Tavern',
# ...
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1334793600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Country Donuts',
#   'restaurant_id': '40395554'},
#  {'address': {'building': '365',
#    'coord': [-73.99543779999999, 40.6791887],
#    'street': 'Smith Street',
#    'zipcode': '11231'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1414454400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1401321600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1365033600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1345420800000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1332115200000}, 'grade': 'A', 'score': 13}],
#   'name': "Frank'S Place",
#   'restaurant_id': '40395568'},
#  {'address': {'building': '83-07',
#    'coord': [-73.8795695, 40.7411095],
#    'street': 'Broadway',
#    'zipcode': '11373'},
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1402531200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1383955200000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1362441600000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1347408000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1316044800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Elmhurst Famous Pizza',
#   'restaurant_id': '40395597'},
#  {'address': {'building': '300',
#    'coord': [-73.8787725, 40.8728659],
#    'street': 'East 204 Street',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1391212800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1358208000000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'address': {'building': '113335',
#    'coord': [-73.96712, 40.798503],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1399852800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336608000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1325203200000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1312848000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Camilles',
#   'restaurant_id': '40395691'},
#  {'address': {'building': '200',
#    'coord': [-73.9875796, 40.7709609],
#    'street': 'West   60 Street',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1406505600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1374796800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1343779200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1333065600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1320796800000}, 'grade': 'A', 'score': 13}],
#   'name': 'Olympic Flame Diner',
#   'restaurant_id': '40395723'},
#  {'address': {'building': '357',
#    'coord': [-73.96642899999999, 40.754211],
#    'street': 'East 50 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1382400000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1364947200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343001600000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1318464000000}, 'grade': 'B', 'score': 15}],
#   'name': 'Indigo Indian Cuisine',
#   'restaurant_id': '40395748'},
#  {'address': {'building': '150',
#    'coord': [-73.9908184, 40.686652],
#    'street': 'Smith Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1381968000000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1367366400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1353456000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1350604800000}, 'grade': 'P', 'score': 0},
#    {'date': {'$date': 1319500800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1306108800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Caruso Pizzeria & Restaurant',
#   'restaurant_id': '40395774'},
#  {'address': {'building': '455',
#    'coord': [-73.98475669999999, 40.6626618],
#    'street': '7 Avenue',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indonesian',
#   'grades': [{'date': {'$date': 1400716800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1367452800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1349222400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1315440000000}, 'grade': 'C', 'score': 29}],
#   'name': 'Java Restaurant',
#   'restaurant_id': '40395826'},
#  {'address': {'building': '34-37',
#    'coord': [-73.7735119, 40.7693963],
#    'street': 'Bell Boulevard',
#    'zipcode': '11361'},
#   'borough': 'Queens',
#   'cuisine': 'Mexican',
#   'grades': [{'date': {'$date': 1414108800000}, 'grade': 'C', 'score': 52},
#    {'date': {'$date': 1393977600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1373068800000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1354924800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1349222400000}, 'grade': 'P', 'score': 3},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Tequilla Sunrise',
#   'restaurant_id': '40395858'},
#  {'address': {'building': '411',
#    'coord': [-73.98352299999999, 40.743549],
#    'street': 'Park Avenue South',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1421107200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1408060800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1377734400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1364515200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1330560000000}, 'grade': 'A', 'score': 2}],
#   'name': 'Les Halles',
#   'restaurant_id': '40395860'},
#  {'address': {'building': '2807',
#    'coord': [-73.94473839999999, 40.6158108],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11229'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1410912000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1395705600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1358899200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1317859200000}, 'grade': 'A', 'score': 10}],
#   'name': 'Pizza Nosh',
#   'restaurant_id': '40395865'},
#  {'address': {'building': '3533',
#    'coord': [-73.9509786, 40.8264242],
#    'street': 'Broadway',
#    'zipcode': '10031'},
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'date': {'$date': 1412035200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1395014400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1375660800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1346889600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1333411200000}, 'grade': 'B', 'score': 22}],
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40395872'},
#  {'address': {'building': '98-08',
#    'coord': [-73.84043869999999, 40.6797863],
#    'street': 'Rockaway Boulevard',
#    'zipcode': '11417'},
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1367971200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1335139200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1305504000000}, 'grade': 'A', 'score': 13}],
#   'name': 'White Castle',
#   'restaurant_id': '40395882'},
#  {'address': {'building': '1454',
#    'coord': [-73.9563642, 40.7712012],
#    'street': '2 Avenue',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418774400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1398729600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1364774400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1350864000000}, 'grade': 'A', 'score': 12}],
#   'name': 'The Stumble Inn',
#   'restaurant_id': '40395892'},
#  {'address': {'building': '7559',
#    'coord': [-73.8754225, 40.713315],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1419292800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1405555200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1389225600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1367280000000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1347667200000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1333324800000}, 'grade': 'B', 'score': 20}],
#   'name': 'Rosa #2 Pizzeria',
#   'restaurant_id': '40395906'},
#  {'address': {'building': '250-01',
#    'coord': [-73.737484, 40.7683787],
#    'street': 'Northern Boulevard',
#    'zipcode': '11362'},
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1403136000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1390867200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1375315200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343001600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1313020800000}, 'grade': 'A', 'score': 0}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395910'},
#  {'address': {'building': '504',
#    'coord': [-73.9194763, 40.807466],
#    'street': 'East  138 Street',
#    'zipcode': '10454'},
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1417132800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1403222400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1387238400000}, 'grade': 'C', 'score': 50},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1337558400000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1325203200000}, 'grade': 'A', 'score': 12}],
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'address': {'building': '1660',
#    'coord': [-74.162854, 40.60778699999999],
#    'street': 'Richmond Avenue',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1401753600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1369267200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1338854400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1324944000000}, 'grade': 'C', 'score': 52}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395935'},
#  {'address': {'building': '2516',
#    'coord': [-73.86709549999999, 40.8640754],
#    'street': 'White Plains Road',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1391644800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1359504000000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1327968000000}, 'grade': 'A', 'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'address': {'building': '84',
#    'coord': [-73.9776503, 40.7521147],
#    'street': 'East 42 Street',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'date': {'$date': 1403049600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1383004800000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1367193600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1324252800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1312761600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Hot & Crusty Bakery',
#   'restaurant_id': '40395996'},
#  {'address': {'building': '65',
#    'coord': [-73.98606099999999, 40.728176],
#    'street': 'St Marks Place',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1403740800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1378771200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1363910400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1346803200000}, 'grade': 'B', 'score': 20}],
#   'name': 'Jules Bistro',
#   'restaurant_id': '40396000'},
#  {'address': {'building': '180',
#    'coord': [-73.98087199999999, 40.775067],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1386374400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1332460800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1305590400000}, 'grade': 'B', 'score': 18}],
#   'name': 'Il Violino',
#   'restaurant_id': '40396019'},
#  {'address': {'building': '78',
#    'coord': [-73.9981541, 40.7351897],
#    'street': 'West   11 Street',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1396569600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1345593600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1329782400000}, 'grade': 'A', 'score': 10}],
#   'name': 'French Roast',
#   'restaurant_id': '40396020'},
#  {'address': {'building': '532',
#    'coord': [-73.9738917, 40.7605744],
#    'street': 'Madison Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1403740800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1383091200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1370563200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1350345600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1336003200000}, 'grade': 'B', 'score': 16},
#    {'date': {'$date': 1324944000000}, 'grade': 'A', 'score': 5}],
#   'name': "Smiler'S Deli",
#   'restaurant_id': '40396037'},
#  {'address': {'building': '780',
#    'coord': [-73.8630529, 40.8456372],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1410220800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1374105600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1361750400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346716800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1333929600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1317081600000}, 'grade': 'A', 'score': 2}],
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'address': {'building': '74',
#    'coord': [-73.9956844, 40.7262603],
#    'street': 'Bleeker Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1396224000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1364428800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1342742400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1328745600000}, 'grade': 'A', 'score': 11}],
#   'name': 'Two Boots To Go-Go',
#   'restaurant_id': '40396066'},
#  {'address': {'building': '10',
#    'coord': [-73.9815103, 40.7475731],
#    'street': 'Park Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1404777600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1375315200000}, 'grade': 'C', 'score': 9},
#    {'date': {'$date': 1358812800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1337299200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1323820800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1312156800000}, 'grade': 'A', 'score': 8}],
#   'name': "Mendy'S",
#   'restaurant_id': '40396074'},
#  ...]

# %% [markdown]
# ### 2. Mostrar los campos restaurant_id, nombre, distrito y cocina, pero excluya el campo _id para todos los documentos de la colección restaurantes

# %%
filtro = {"borough": "Bronx"}
proyeccion = {"_id":0, "restaurant_id":1,"name":1,"borough":1,"cuisine":1 }
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub',
#   'restaurant_id': '40365893'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl',
#   'restaurant_id': '40366497'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime',
#   'restaurant_id': '40366748'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40366833'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop",
#   'restaurant_id': '40366938'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray',
#   'restaurant_id': '40367161'},
#  {'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest",
#   'restaurant_id': '40367946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe',
#   'restaurant_id': '40368018'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond',
#   'restaurant_id': '40368025'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant',
#   'restaurant_id': '40369087'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant',
#   'restaurant_id': '40369299'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill',
#   'restaurant_id': '40369601'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant",
#   'restaurant_id': '40369641'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40369669'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill",
#   'restaurant_id': '40369895'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40369915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub",
#   'restaurant_id': '40370150'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40372196'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza',
#   'restaurant_id': '40372631'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40373938'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant",
#   'restaurant_id': '40374136'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant',
#   'restaurant_id': '40374259'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant',
#   'restaurant_id': '40375136'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant",
#   'restaurant_id': '40377124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant',
#   'restaurant_id': '40377243'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40378347'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40379573'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North',
#   'restaurant_id': '40379894'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos',
#   'restaurant_id': '40380164'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner',
#   'restaurant_id': '40380253'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner',
#   'restaurant_id': '40382517'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza",
#   'restaurant_id': '40382652'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken",
#   'restaurant_id': '40382900'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant',
#   'restaurant_id': '40383819'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant',
#   'restaurant_id': '40384486'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor',
#   'restaurant_id': '40385680'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria",
#   'restaurant_id': '40385955'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza',
#   'restaurant_id': '40386278'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl",
#   'restaurant_id': '40386672'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387143'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza",
#   'restaurant_id': '40387399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant',
#   'restaurant_id': '40387477'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop',
#   'restaurant_id': '40387528'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40388016'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place',
#   'restaurant_id': '40388253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40388269'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt',
#   'restaurant_id': '40388392'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant",
#   'restaurant_id': '40388462'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe',
#   'restaurant_id': '40389011'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza",
#   'restaurant_id': '40389365'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Rino'S",
#   'restaurant_id': '40389594'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Villa Barone Manor',
#   'restaurant_id': '40390266'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood',
#   'restaurant_id': '40390814'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Gleason'S Cafe",
#   'restaurant_id': '40391375'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40391639'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham Seafood And Chicken',
#   'restaurant_id': '40392190'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Gun Post Lanes Snack Bar',
#   'restaurant_id': '40393563'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "O'Brien'S Pub",
#   'restaurant_id': '40394024'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Tibbett Diner',
#   'restaurant_id': '40394030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'E & L Bakery & Coffee Shop',
#   'restaurant_id': '40394761'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wembley Athletic Club',
#   'restaurant_id': '40394770'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cullen'S Tavern",
#   'restaurant_id': '40394838'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40395511'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40396399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pugsley Pizza',
#   'restaurant_id': '40396548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40397219'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Dominick'S Bar & Restaurant",
#   'restaurant_id': '40397574'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Zaro'S Bread Basket",
#   'restaurant_id': '40397863'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Lechonera Criolla',
#   'restaurant_id': '40398642'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Enzo Cafe',
#   'restaurant_id': '40398852'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Joe'S Pizza",
#   'restaurant_id': '40398910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Lolita'S Restaurant",
#   'restaurant_id': '40398958'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40399778'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Rolen Bagels',
#   'restaurant_id': '40399988'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Fordham Fried Chicken & Sea Food',
#   'restaurant_id': '40400799'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Celeste'S Snack Bar",
#   'restaurant_id': '40401250'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Pelham Bay Diner',
#   'restaurant_id': '40401316'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40402106'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Villa Barone',
#   'restaurant_id': '40402187'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Stuyvesant Yacht Club',
#   'restaurant_id': '40402679'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Yacht Club',
#   'restaurant_id': '40402699'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Ambassador Diner',
#   'restaurant_id': '40403946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Bagel Corner',
#   'restaurant_id': '40423450'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Kingston Tropical Bakery',
#   'restaurant_id': '40423481'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Concourse Jamaican Bakery',
#   'restaurant_id': '40423547'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Artuso Pastry Shop',
#   'restaurant_id': '40423571'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Champion Bakery',
#   'restaurant_id': '40423830'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Al Cholo Bakery',
#   'restaurant_id': '40424273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Franco Bakery',
#   'restaurant_id': '40424765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Biarritz Bakery',
#   'restaurant_id': '40424919'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Jackie'S West Indian Bakery",
#   'restaurant_id': '40424972'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Vaquero Barras',
#   'restaurant_id': '40510301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Pitusa Bakery',
#   'restaurant_id': '40510823'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Woodlawn Cafe',
#   'restaurant_id': '40512207'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40512610'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Crown Diner',
#   'restaurant_id': '40512746'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40515211'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Artie'S",
#   'restaurant_id': '40515670'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Crosstown Diner',
#   'restaurant_id': '40515675'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Catania'S Pizza Cafe",
#   'restaurant_id': '40521624'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Jimmy Ryan'S",
#   'restaurant_id': '40524837'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Park Billiards',
#   'restaurant_id': '40524910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40524973'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Full Moon Pizza',
#   'restaurant_id': '40525206'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Capri Ii Pizza',
#   'restaurant_id': '40525767'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Dragon City',
#   'restaurant_id': '40529203'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Nacional Bakery #1',
#   'restaurant_id': '40530630'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'New Pabellon De Oro Restaurant',
#   'restaurant_id': '40535823'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cosmos Restaurant',
#   'restaurant_id': '40538061'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bowler Land',
#   'restaurant_id': '40539772'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Feeding Tree Style West Indian Restaurant',
#   'restaurant_id': '40541088'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Rio Cobre Restaurant',
#   'restaurant_id': '40545598'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pasta Pasta Restaurant',
#   'restaurant_id': '40545786'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Ray'S Pizza Restuarant",
#   'restaurant_id': '40548730'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Louie'Sdale Diner",
#   'restaurant_id': '40549539'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Montezuma Restaurant',
#   'restaurant_id': '40549885'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40549913'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40550801'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hunan Balcony',
#   'restaurant_id': '40551996'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Great Wall Restaurant',
#   'restaurant_id': '40552226'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Boston Market',
#   'restaurant_id': '40553581'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Bella Rosa Bakery',
#   'restaurant_id': '40554018'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Kennedy Fried Chicken',
#   'restaurant_id': '40557466'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Isla Cuchifritos',
#   'restaurant_id': '40557901'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Keenans',
#   'restaurant_id': '40558516'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40559279'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40560308'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Lena Restaurant',
#   'restaurant_id': '40560823'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'La Perla Mexicana',
#   'restaurant_id': '40566706'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Sugar City Bakery',
#   'restaurant_id': '40568460'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Lopez'S Pizzeria And Coffee Shop",
#   'restaurant_id': '40568964'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Glen Roy Bar And Grill',
#   'restaurant_id': '40569838'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'An Beal Bocht Cafe',
#   'restaurant_id': '40570634'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Diamante Poblano Restaurant',
#   'restaurant_id': '40570910'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Archer Sports Bar',
#   'restaurant_id': '40571081'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lucky House Restaurant',
#   'restaurant_id': '40571587'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Shamrock Inn',
#   'restaurant_id': '40572406'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Wah Kitchen',
#   'restaurant_id': '40573101'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Crab Shanty',
#   'restaurant_id': '40573338'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Throgs Neck Clipper',
#   'restaurant_id': '40574209'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cafe Lou'S",
#   'restaurant_id': '40575255'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Barries Restaurant',
#   'restaurant_id': '40576056'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Giralda Bakery',
#   'restaurant_id': '40578388'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'New Capital Restaurant',
#   'restaurant_id': '40585102'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Pelham Bake Shop',
#   'restaurant_id': '40587400'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40592181'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Yolanda Pizzeria Restaurant',
#   'restaurant_id': '40594879'},
#  {'borough': 'Bronx',
#   'cuisine': 'Greek',
#   'name': 'Gyro King',
#   'restaurant_id': '40596246'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40598230'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'City Island Diner /Snug Bar',
#   'restaurant_id': '40604207'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P.J. Brady'S Tavern",
#   'restaurant_id': '40607093'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bedford Cafe & Restaurant',
#   'restaurant_id': '40608422'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Capri Pizza Restaurant',
#   'restaurant_id': '40617679'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pasquale Rigoletto Restaurant',
#   'restaurant_id': '40618281'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Webster Cafe',
#   'restaurant_id': '40618714'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40620484'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Caffe Egidio',
#   'restaurant_id': '40621241'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Black Whale',
#   'restaurant_id': '40622037'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Express',
#   'restaurant_id': '40623708'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Billy'S Sport Bar Restaurant & Lounge",
#   'restaurant_id': '40624470'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Italia 1',
#   'restaurant_id': '40634607'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Steve'S Bakery",
#   'restaurant_id': '40644030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Sabrosura',
#   'restaurant_id': '40645073'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Blimpie',
#   'restaurant_id': '40649156'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Los Girasoles Restaurant',
#   'restaurant_id': '40653926'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40654198'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Cafe Al Mercato',
#   'restaurant_id': '40654328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': "Sam'S Restaurant",
#   'restaurant_id': '40655946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': 'Riverdale Steak House',
#   'restaurant_id': '40656594'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Pepe Joes Pizzeria',
#   'restaurant_id': '40663973'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Gino'S Pastry Shop",
#   'restaurant_id': '40665681'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40665719'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': "Loeser'S Hebrew National",
#   'restaurant_id': '40666155'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40669100'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Firozas Roti Bar',
#   'restaurant_id': '40669394'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40671411'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Market Restaurant (C-D Block)',
#   'restaurant_id': '40674404'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': "Behan'S Pub",
#   'restaurant_id': '40675225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Other',
#   'name': "Johnny'S O'S",
#   'restaurant_id': '40678067'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Joe'S Place",
#   'restaurant_id': '40680764'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40684999'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bartow Pizza',
#   'restaurant_id': '40687266'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Fella'S Bar",
#   'restaurant_id': '40689434'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Checkers',
#   'restaurant_id': '40690910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Sammy'S Fishbox",
#   'restaurant_id': '40691110'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Snack Bar (Located Between A-B Between Fancy Food And Masters)',
#   'restaurant_id': '40693095'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "J.R'S Cabaret",
#   'restaurant_id': '40693952'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Gary And Gino'S",
#   'restaurant_id': '40694187'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Parrilla Latina Steakhouse',
#   'restaurant_id': '40694273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Nick Garden Coffee Shop',
#   'restaurant_id': '40699339'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Latino Restaurant',
#   'restaurant_id': '40699772'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Hing Restaurant',
#   'restaurant_id': '40701165'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Emilia'S Restaurant",
#   'restaurant_id': '40705438'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Mi Pueblito Bakery/Comida Tipica Mexicana',
#   'restaurant_id': '40705983'},
#  {'borough': 'Bronx',
#   'cuisine': 'Barbecue',
#   'name': 'The Barbecue Pit',
#   'restaurant_id': '40716007'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pine Bar & Grill',
#   'restaurant_id': '40717234'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Prospect Coffee Shop',
#   'restaurant_id': '40719693'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Barnes & Noble Booksellers',
#   'restaurant_id': '40722176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40724205'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Market Place Pizza',
#   'restaurant_id': '40725375'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Jolly Tinker',
#   'restaurant_id': '40730115'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Angelica'S Bakery",
#   'restaurant_id': '40730301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Captain'S Pizzeria And Restaurant",
#   'restaurant_id': '40731746'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40734703'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Portofino Cafe',
#   'restaurant_id': '40736253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Ali'S Roti Shop",
#   'restaurant_id': '40738028'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Teresa'S Gourmet",
#   'restaurant_id': '40740446'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Susie'S Pies",
#   'restaurant_id': '40741630'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40742990'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40742997'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40743000'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40743359'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Picanteria El Botecito',
#   'restaurant_id': '40744238'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Nonis Coffee Shop',
#   'restaurant_id': '40747192'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Diner',
#   'restaurant_id': '40747940'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Applebee'S Neighborhood Grill & Bar",
#   'restaurant_id': '40752494'},
#  {'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Bally Total Fitness',
#   'restaurant_id': '40752699'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Morris Park Pizza',
#   'restaurant_id': '40754765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Circle Pizzeria',
#   'restaurant_id': '40755548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bella Napoli',
#   'restaurant_id': '40759930'},
#  {'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Astral Fitness & Wellness',
#   'restaurant_id': '40760469'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hong Kong Restaurant',
#   'restaurant_id': '40765358'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad',
#   'restaurant_id': '40781213'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Dancing Crane Cafe (Bx Zoo)',
#   'restaurant_id': '40793858'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40794103'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40794912'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Section 5 Pizza Restaurant',
#   'restaurant_id': '40799031'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Step In Restaurant & Lounge',
#   'restaurant_id': '40800483'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40800986'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40801605'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Kristy'S Restaurant",
#   'restaurant_id': '40804049'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'San German Cuchifrito',
#   'restaurant_id': '40810657'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'J & J Restaurant & Cuchifritos',
#   'restaurant_id': '40812317'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40814300'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Boulevard Tavern',
#   'restaurant_id': '40815627'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Shore Haven Diner',
#   'restaurant_id': '40815664'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': "Jake'S Steakhouse",
#   'restaurant_id': '40819558'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Madison'S",
#   'restaurant_id': '40823884'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'East Dynasty',
#   'restaurant_id': '40827529'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40828609'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'Ebe Ye Yie African Restaurant',
#   'restaurant_id': '40832718'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Malecon Restaurant',
#   'restaurant_id': '40837042'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'City Island Deli',
#   'restaurant_id': '40839264'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Gurra Cafe',
#   'restaurant_id': '40840124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura',
#   'restaurant_id': '40842437'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'To Go Express',
#   'restaurant_id': '40843062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chirping Chicken',
#   'restaurant_id': '40847914'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Peacock Restaurant',
#   'restaurant_id': '40849313'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40849624'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40850448'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Williamsbridge Tavern',
#   'restaurant_id': '40852754'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Vista Hermosa Deli Restaurant',
#   'restaurant_id': '40853915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Vivienne'S",
#   'restaurant_id': '40856176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40856325'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Lin'S Garden",
#   'restaurant_id': '40857406'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40860841'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Casa Promesa',
#   'restaurant_id': '40861141'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Subway',
#   'restaurant_id': '40862204'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Shalon Restaurant',
#   'restaurant_id': '40863225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Broadway Pizza & Pasta',
#   'restaurant_id': '40863575'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863944'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863963'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866315'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866322'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866340'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Mi Sueno Restaurant',
#   'restaurant_id': '40866951'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40868904'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40869179'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mr Mcgoo'S",
#   'restaurant_id': '40869211'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Buen Ambiente',
#   'restaurant_id': '40869790'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Popeyes Chicken & Biscuits',
#   'restaurant_id': '40869873'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Liberato Restaurant',
#   'restaurant_id': '40871403'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Wilbel Pizza',
#   'restaurant_id': '40871979'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Mcginley Center',
#   'restaurant_id': '40874831'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University/Mcginley Center/Ramskeller Kitchen',
#   'restaurant_id': '40874915'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seafood  City',
#   'restaurant_id': '40875290'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel',
#   'restaurant_id': '40876932'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Millenium Grill',
#   'restaurant_id': '40877246'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Fordham University - Student Deli',
#   'restaurant_id': '40877285'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Nueva Giralda Bakery',
#   'restaurant_id': '40877421'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Sheas Emerald',
#   'restaurant_id': '40883581'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Memories Lounge',
#   'restaurant_id': '40883866'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Roca Tone Seafood Restaurant',
#   'restaurant_id': '40885478'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Best Italian Pizza',
#   'restaurant_id': '40886422'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'J.E. Bakery',
#   'restaurant_id': '40890186'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': 'Cea Lo Cafe',
#   'restaurant_id': '40890407'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mug-Z'S Sports Bar",
#   'restaurant_id': '40891377'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Frank'S Pizzeria",
#   'restaurant_id': '40892887'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Nb. National Bakery',
#   'restaurant_id': '40897418'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Rainbow Restaurant',
#   'restaurant_id': '40899178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub',
#   'restaurant_id': '40365893'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl',
#   'restaurant_id': '40366497'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime',
#   'restaurant_id': '40366748'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40366833'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop",
#   'restaurant_id': '40366938'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray',
#   'restaurant_id': '40367161'},
#  {'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest",
#   'restaurant_id': '40367946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe',
#   'restaurant_id': '40368018'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond',
#   'restaurant_id': '40368025'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant',
#   'restaurant_id': '40369087'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant',
#   'restaurant_id': '40369299'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill',
#   'restaurant_id': '40369601'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant",
#   'restaurant_id': '40369641'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40369669'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill",
#   'restaurant_id': '40369895'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40369915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub",
#   'restaurant_id': '40370150'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40372196'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza',
#   'restaurant_id': '40372631'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40373938'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant",
#   'restaurant_id': '40374136'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant',
#   'restaurant_id': '40374259'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant',
#   'restaurant_id': '40375136'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant",
#   'restaurant_id': '40377124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant',
#   'restaurant_id': '40377243'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40378347'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40379573'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North',
#   'restaurant_id': '40379894'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos',
#   'restaurant_id': '40380164'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner',
#   'restaurant_id': '40380253'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner',
#   'restaurant_id': '40382517'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza",
#   'restaurant_id': '40382652'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken",
#   'restaurant_id': '40382900'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant',
#   'restaurant_id': '40383819'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant',
#   'restaurant_id': '40384486'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor',
#   'restaurant_id': '40385680'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria",
#   'restaurant_id': '40385955'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza',
#   'restaurant_id': '40386278'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl",
#   'restaurant_id': '40386672'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387143'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza",
#   'restaurant_id': '40387399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant',
#   'restaurant_id': '40387477'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop',
#   'restaurant_id': '40387528'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40388016'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place',
#   'restaurant_id': '40388253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40388269'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt',
#   'restaurant_id': '40388392'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant",
#   'restaurant_id': '40388462'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe',
#   'restaurant_id': '40389011'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza",
#   'restaurant_id': '40389365'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Rino'S",
#   'restaurant_id': '40389594'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Villa Barone Manor',
#   'restaurant_id': '40390266'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood',
#   'restaurant_id': '40390814'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Gleason'S Cafe",
#   'restaurant_id': '40391375'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40391639'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham Seafood And Chicken',
#   'restaurant_id': '40392190'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Gun Post Lanes Snack Bar',
#   'restaurant_id': '40393563'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "O'Brien'S Pub",
#   'restaurant_id': '40394024'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Tibbett Diner',
#   'restaurant_id': '40394030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'E & L Bakery & Coffee Shop',
#   'restaurant_id': '40394761'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wembley Athletic Club',
#   'restaurant_id': '40394770'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cullen'S Tavern",
#   'restaurant_id': '40394838'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40395511'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40396399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pugsley Pizza',
#   'restaurant_id': '40396548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40397219'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Dominick'S Bar & Restaurant",
#   'restaurant_id': '40397574'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Zaro'S Bread Basket",
#   'restaurant_id': '40397863'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Lechonera Criolla',
#   'restaurant_id': '40398642'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Enzo Cafe',
#   'restaurant_id': '40398852'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Joe'S Pizza",
#   'restaurant_id': '40398910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Lolita'S Restaurant",
#   'restaurant_id': '40398958'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40399778'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Rolen Bagels',
#   'restaurant_id': '40399988'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Fordham Fried Chicken & Sea Food',
#   'restaurant_id': '40400799'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Celeste'S Snack Bar",
#   'restaurant_id': '40401250'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Pelham Bay Diner',
#   'restaurant_id': '40401316'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40402106'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Villa Barone',
#   'restaurant_id': '40402187'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Stuyvesant Yacht Club',
#   'restaurant_id': '40402679'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Yacht Club',
#   'restaurant_id': '40402699'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Ambassador Diner',
#   'restaurant_id': '40403946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Bagel Corner',
#   'restaurant_id': '40423450'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Kingston Tropical Bakery',
#   'restaurant_id': '40423481'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Concourse Jamaican Bakery',
#   'restaurant_id': '40423547'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Artuso Pastry Shop',
#   'restaurant_id': '40423571'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Champion Bakery',
#   'restaurant_id': '40423830'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Al Cholo Bakery',
#   'restaurant_id': '40424273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Franco Bakery',
#   'restaurant_id': '40424765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Biarritz Bakery',
#   'restaurant_id': '40424919'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Jackie'S West Indian Bakery",
#   'restaurant_id': '40424972'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Vaquero Barras',
#   'restaurant_id': '40510301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Pitusa Bakery',
#   'restaurant_id': '40510823'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Woodlawn Cafe',
# ...
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pasquale Rigoletto Restaurant',
#   'restaurant_id': '40618281'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Webster Cafe',
#   'restaurant_id': '40618714'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40620484'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Caffe Egidio',
#   'restaurant_id': '40621241'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Black Whale',
#   'restaurant_id': '40622037'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Express',
#   'restaurant_id': '40623708'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Billy'S Sport Bar Restaurant & Lounge",
#   'restaurant_id': '40624470'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Italia 1',
#   'restaurant_id': '40634607'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Steve'S Bakery",
#   'restaurant_id': '40644030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Sabrosura',
#   'restaurant_id': '40645073'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Blimpie',
#   'restaurant_id': '40649156'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Los Girasoles Restaurant',
#   'restaurant_id': '40653926'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40654198'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Cafe Al Mercato',
#   'restaurant_id': '40654328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': "Sam'S Restaurant",
#   'restaurant_id': '40655946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': 'Riverdale Steak House',
#   'restaurant_id': '40656594'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Pepe Joes Pizzeria',
#   'restaurant_id': '40663973'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Gino'S Pastry Shop",
#   'restaurant_id': '40665681'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40665719'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': "Loeser'S Hebrew National",
#   'restaurant_id': '40666155'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40669100'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Firozas Roti Bar',
#   'restaurant_id': '40669394'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40671411'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Market Restaurant (C-D Block)',
#   'restaurant_id': '40674404'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': "Behan'S Pub",
#   'restaurant_id': '40675225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Other',
#   'name': "Johnny'S O'S",
#   'restaurant_id': '40678067'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Joe'S Place",
#   'restaurant_id': '40680764'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40684999'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bartow Pizza',
#   'restaurant_id': '40687266'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Fella'S Bar",
#   'restaurant_id': '40689434'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Checkers',
#   'restaurant_id': '40690910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Sammy'S Fishbox",
#   'restaurant_id': '40691110'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Snack Bar (Located Between A-B Between Fancy Food And Masters)',
#   'restaurant_id': '40693095'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "J.R'S Cabaret",
#   'restaurant_id': '40693952'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Gary And Gino'S",
#   'restaurant_id': '40694187'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Parrilla Latina Steakhouse',
#   'restaurant_id': '40694273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Nick Garden Coffee Shop',
#   'restaurant_id': '40699339'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Latino Restaurant',
#   'restaurant_id': '40699772'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Hing Restaurant',
#   'restaurant_id': '40701165'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Emilia'S Restaurant",
#   'restaurant_id': '40705438'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Mi Pueblito Bakery/Comida Tipica Mexicana',
#   'restaurant_id': '40705983'},
#  {'borough': 'Bronx',
#   'cuisine': 'Barbecue',
#   'name': 'The Barbecue Pit',
#   'restaurant_id': '40716007'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pine Bar & Grill',
#   'restaurant_id': '40717234'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Prospect Coffee Shop',
#   'restaurant_id': '40719693'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Barnes & Noble Booksellers',
#   'restaurant_id': '40722176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40724205'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Market Place Pizza',
#   'restaurant_id': '40725375'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Jolly Tinker',
#   'restaurant_id': '40730115'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Angelica'S Bakery",
#   'restaurant_id': '40730301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Captain'S Pizzeria And Restaurant",
#   'restaurant_id': '40731746'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40734703'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Portofino Cafe',
#   'restaurant_id': '40736253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Ali'S Roti Shop",
#   'restaurant_id': '40738028'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Teresa'S Gourmet",
#   'restaurant_id': '40740446'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Susie'S Pies",
#   'restaurant_id': '40741630'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40742990'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40742997'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40743000'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40743359'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Picanteria El Botecito',
#   'restaurant_id': '40744238'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Nonis Coffee Shop',
#   'restaurant_id': '40747192'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Diner',
#   'restaurant_id': '40747940'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Applebee'S Neighborhood Grill & Bar",
#   'restaurant_id': '40752494'},
#  {'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Bally Total Fitness',
#   'restaurant_id': '40752699'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Morris Park Pizza',
#   'restaurant_id': '40754765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Circle Pizzeria',
#   'restaurant_id': '40755548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bella Napoli',
#   'restaurant_id': '40759930'},
#  {'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Astral Fitness & Wellness',
#   'restaurant_id': '40760469'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hong Kong Restaurant',
#   'restaurant_id': '40765358'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad',
#   'restaurant_id': '40781213'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Dancing Crane Cafe (Bx Zoo)',
#   'restaurant_id': '40793858'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40794103'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40794912'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Section 5 Pizza Restaurant',
#   'restaurant_id': '40799031'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Step In Restaurant & Lounge',
#   'restaurant_id': '40800483'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40800986'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40801605'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Kristy'S Restaurant",
#   'restaurant_id': '40804049'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'San German Cuchifrito',
#   'restaurant_id': '40810657'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'J & J Restaurant & Cuchifritos',
#   'restaurant_id': '40812317'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40814300'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Boulevard Tavern',
#   'restaurant_id': '40815627'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Shore Haven Diner',
#   'restaurant_id': '40815664'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': "Jake'S Steakhouse",
#   'restaurant_id': '40819558'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Madison'S",
#   'restaurant_id': '40823884'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'East Dynasty',
#   'restaurant_id': '40827529'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40828609'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'Ebe Ye Yie African Restaurant',
#   'restaurant_id': '40832718'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Malecon Restaurant',
#   'restaurant_id': '40837042'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'City Island Deli',
#   'restaurant_id': '40839264'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Gurra Cafe',
#   'restaurant_id': '40840124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura',
#   'restaurant_id': '40842437'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'To Go Express',
#   'restaurant_id': '40843062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chirping Chicken',
#   'restaurant_id': '40847914'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Peacock Restaurant',
#   'restaurant_id': '40849313'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40849624'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40850448'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Williamsbridge Tavern',
#   'restaurant_id': '40852754'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Vista Hermosa Deli Restaurant',
#   'restaurant_id': '40853915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Vivienne'S",
#   'restaurant_id': '40856176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40856325'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Lin'S Garden",
#   'restaurant_id': '40857406'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40860841'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Casa Promesa',
#   'restaurant_id': '40861141'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Subway',
#   'restaurant_id': '40862204'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Shalon Restaurant',
#   'restaurant_id': '40863225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Broadway Pizza & Pasta',
#   'restaurant_id': '40863575'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863944'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863963'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866315'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866322'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866340'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Mi Sueno Restaurant',
#   'restaurant_id': '40866951'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40868904'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40869179'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mr Mcgoo'S",
#   'restaurant_id': '40869211'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Buen Ambiente',
#   'restaurant_id': '40869790'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Popeyes Chicken & Biscuits',
#   'restaurant_id': '40869873'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Liberato Restaurant',
#   'restaurant_id': '40871403'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Wilbel Pizza',
#   'restaurant_id': '40871979'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Mcginley Center',
#   'restaurant_id': '40874831'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University/Mcginley Center/Ramskeller Kitchen',
#   'restaurant_id': '40874915'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seafood  City',
#   'restaurant_id': '40875290'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel',
#   'restaurant_id': '40876932'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Millenium Grill',
#   'restaurant_id': '40877246'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Fordham University - Student Deli',
#   'restaurant_id': '40877285'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Nueva Giralda Bakery',
#   'restaurant_id': '40877421'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Sheas Emerald',
#   'restaurant_id': '40883581'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Memories Lounge',
#   'restaurant_id': '40883866'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Roca Tone Seafood Restaurant',
#   'restaurant_id': '40885478'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Best Italian Pizza',
#   'restaurant_id': '40886422'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'J.E. Bakery',
#   'restaurant_id': '40890186'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': 'Cea Lo Cafe',
#   'restaurant_id': '40890407'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mug-Z'S Sports Bar",
#   'restaurant_id': '40891377'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Frank'S Pizzeria",
#   'restaurant_id': '40892887'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Nb. National Bakery',
#   'restaurant_id': '40897418'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Rainbow Restaurant',
#   'restaurant_id': '40899178'}]

# %% [markdown]
# ### 3. Mostrar los primeros 5 restaurantes que se encuentran en el distrito Bronx

# %%
list(restaurantes.find({'borough':'Bronx'},{'_id':0}).limit(5).sort("name"))
# Out:
# [{'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400630400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1369699200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1339977600000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1307404800000}, 'grade': 'A', 'score': 9}],
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400630400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1369699200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1339977600000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1307404800000}, 'grade': 'A', 'score': 9}],
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'grades': [{'date': {'$date': 1400630400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1370044800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1339459200000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1307491200000}, 'grade': 'A', 'score': 0}],
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'grades': [{'date': {'$date': 1400630400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1370044800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1339459200000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1307491200000}, 'grade': 'A', 'score': 0}],
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'address': {'building': '3825',
#    'coord': [-73.86267, 40.884484],
#    'street': 'White Plains Road',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'grades': [{'date': {'$date': 1415232000000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1402876800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1382313600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1369008000000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1334620800000}, 'grade': 'A', 'score': 10}],
#   'name': 'Al Cholo Bakery',
#   'restaurant_id': '40424273'}]

# %% [markdown]
# ### 4. Devolver los restaurantes que lograron una puntuación superior a 80 pero inferior a 100

# %%
filtro = {"grades.score": {"$gt":90}}
proyeccion={"name":1, "grades":1, "_id":0}
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'grades': [{'date': {'$date': 1408665600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1395964800000}, 'grade': 'C', 'score': 131},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1365379200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1350259200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 13}],
#   'name': "Murals On 54/Randolphs'S"},
#  {'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'P', 'score': 2},
#    {'date': {'$date': 1349049600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1333670400000}, 'grade': 'C', 'score': 92},
#    {'date': {'$date': 1320278400000}, 'grade': 'C', 'score': 41}],
#   'name': 'Gandhi'},
#  {'grades': [{'date': {'$date': 1419379200000}, 'grade': 'Z', 'score': 31},
#    {'date': {'$date': 1402963200000}, 'grade': 'C', 'score': 98},
#    {'date': {'$date': 1386806400000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1369180800000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bella Napoli'},
#  {'grades': [{'date': {'$date': 1408665600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1395964800000}, 'grade': 'C', 'score': 131},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1365379200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1350259200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 13}],
#   'name': "Murals On 54/Randolphs'S"},
#  {'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'P', 'score': 2},
#    {'date': {'$date': 1349049600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1333670400000}, 'grade': 'C', 'score': 92},
#    {'date': {'$date': 1320278400000}, 'grade': 'C', 'score': 41}],
#   'name': 'Gandhi'},
#  {'grades': [{'date': {'$date': 1419379200000}, 'grade': 'Z', 'score': 31},
#    {'date': {'$date': 1402963200000}, 'grade': 'C', 'score': 98},
#    {'date': {'$date': 1386806400000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1369180800000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bella Napoli'}]

# %% [markdown]
# ### 5. Devolver los restaurantes que se ubican en un valor de latitud inferior a -95.754168

# %%
proyeccion = {"_id":0}

filtro = {"address.coord.0": {"$lt": -95.754168}}


list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'address': {'building': '3707',
#    'coord': [-101.8945214, 33.5197474],
#    'street': '82 Street',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401840000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1383782400000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1368748800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1333411200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1321401600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Burger King',
#   'restaurant_id': '40534067'},
#  {'address': {'building': '15259',
#    'coord': [-119.6368672, 36.2504996],
#    'street': '10 Avenue',
#    'zipcode': '11357'},
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1409788800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1362355200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1348704000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1322006400000}, 'grade': 'C', 'score': 34}],
#   'name': "Cascarino'S",
#   'restaurant_id': '40668681'},
#  {'address': {'building': '60',
#    'coord': [-111.9975205, 42.0970258],
#    'street': 'West Side Highway',
#    'zipcode': '10006'},
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'grades': [{'date': {'$date': 1395273600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1372377600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1341446400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1311724800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Sports Center At Chelsea Piers (Sushi Bar)',
#   'restaurant_id': '40882356'},
#  {'address': {'building': '3707',
#    'coord': [-101.8945214, 33.5197474],
#    'street': '82 Street',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401840000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1383782400000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1368748800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1333411200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1321401600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Burger King',
#   'restaurant_id': '40534067'},
#  {'address': {'building': '15259',
#    'coord': [-119.6368672, 36.2504996],
#    'street': '10 Avenue',
#    'zipcode': '11357'},
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1409788800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1362355200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1348704000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1322006400000}, 'grade': 'C', 'score': 34}],
#   'name': "Cascarino'S",
#   'restaurant_id': '40668681'},
#  {'address': {'building': '60',
#    'coord': [-111.9975205, 42.0970258],
#    'street': 'West Side Highway',
#    'zipcode': '10006'},
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'grades': [{'date': {'$date': 1395273600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1372377600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1341446400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1311724800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Sports Center At Chelsea Piers (Sushi Bar)',
#   'restaurant_id': '40882356'}]

# %% [markdown]
# ### 6. Devolver los restaurantes que no preparan cocina americana y lograron una puntuación superior a 70 y se ubicaron en una longitud inferior a -65.754168. Nota: Realice esta consulta sin usar el operador $and

# %%
proyeccion = {}

filtro = {
    "cuisine": {"$not": {"$eq":"American"}},
    "grades.score": {"$gt": 70}, 
    "address.coord.1": {"$lt": -65.754168}
}

list(restaurantes.find(proyeccion, filtro))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[40], line 9
#       1 proyeccion = {}
#       3 filtro = {
#       4     "cuisine": {"$not": {"$eq":"American"}},
#       5     "grades.score": {"$gt": 70},
#       6     "address.coord.1": {"$lt": -65.754168}
#       7 }
# ----> 9 list(restaurantes.find(proyeccion, filtro))
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1205, in Cursor._refresh(self)
#    1183         raise InvalidOperation(
#    1184             "Passing a 'hint' is required when using the min/max query"
#    1185             " option to ensure the query utilizes the correct index"
#    1186         )
#    1187     q = self._query_class(
#    1188         self._query_flags,
#    1189         self._collection.database.name,
#    (...)
#    1203         self._exhaust,
#    1204     )
# -> 1205     self._send_message(q)
#    1206 elif self._id:  # Get More
#    1207     if self._limit:
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)
#    1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1745, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1738 def _cmd(
#    1739     _session: Optional[ClientSession],
#    1740     server: Server,
#    1741     conn: Connection,
#    1742     read_preference: _ServerMode,
#    1743 ) -> Response:
#    1744     operation.reset()  # Reset op in case of retry.
# -> 1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    1748         read_preference,
#    1749         self._event_listeners,
#    1750         unpack_res,
#    1751         self,
#    1752     )
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/synchronous/server.py:227, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     225         first = docs[0]
#     226         operation.client._process_response(first, operation.session)  # type: ignore[misc, arg-type]
# --> 227         _check_command_response(first, conn.max_wire_version)
#     228 except Exception as exc:
#     229     duration = datetime.now() - start
#
# File /opt/miniconda3/envs/general.env/lib/python3.11/site-packages/pymongo/helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Expression $eq takes exactly 2 arguments. 1 were passed in., full error: {'ok': 0.0, 'errmsg': 'Expression $eq takes exactly 2 arguments. 1 were passed in.', 'code': 16020, 'codeName': 'Location16020', '$clusterTime': {'clusterTime': Timestamp(1731517113, 8), 'signature': {'hash': b'\xa7K\xc5y\xd6\x7fG\xd5\xac\xe5\xef`\xee4|<\xd6\xe9\xd6/', 'keyId': 7377379910324584451}}, 'operationTime': Timestamp(1731517113, 8)}

# %% [markdown]
# ### 7. Devolver los restaurantes que no preparan cocina americana y lograron un punto de calificación 'A' que no pertenece al distrito de Brooklyn. El documento debe mostrarse según la cocina en orden descendente.

# %%
filtro =  {"cuisine": {"$not":{"$eq":"American"}}, "grades":"A", "borough":{"$not":{"$eq":"Brooklyn"}}}

proyeccion = {}

list(restaurantes.find(filtro,proyeccion))
# Out:
# []

# %% [markdown]
# ### 8. Devolver los restaurantes que pertenecen al distrito Bronx y preparan platos americanos o chinos

# %%
filtro = {"borough":"Bronx", "$or":[{"cuisine":"Chinese"}, {"cuisine":"American"}] }

proyeccion = {"_id": 0}

list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'address': {'building': '1236',
#    'coord': [-73.8893654, 40.81376179999999],
#    'street': '238 Spofford Ave',
#    'zipcode': '10474'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1388361600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1339459200000}, 'grade': 'B', 'score': 15}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'address': {'building': '277',
#    'coord': [-73.8941893, 40.8634684],
#    'street': 'East Kingsbridge Road',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1363651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'address': {'building': '2459',
#    'coord': [-73.8929629, 40.8601605],
#    'street': 'Webster Avenue',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1419292800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1389052800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1356652800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1342569600000}, 'grade': 'A', 'score': 13}],
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'address': {'building': '2102',
#    'coord': [-73.82609699999999, 40.8687177],
#    'street': 'Bartow Ave',
#    'zipcode': '10475'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1407110400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1392940800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1369872000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12}],
#   'name': 'Dragon City',
#   'restaurant_id': '40529203'},
#  {'address': {'building': '3511',
#    'coord': [-73.9100876, 40.8860444],
#    'street': 'Johnson Avenue',
#    'zipcode': '10463'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1404259200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1383696000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1364515200000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1340150400000}, 'grade': 'B', 'score': 27}],
#   'name': 'Hunan Balcony',
#   'restaurant_id': '40551996'},
#  {'address': {'building': '732',
#    'coord': [-73.883128, 40.85353],
#    'street': 'East  187 Street',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1415318400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400112000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1384732800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1370822400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1347840000000}, 'grade': 'B', 'score': 19}],
#   'name': 'Great Wall Restaurant',
#   'restaurant_id': '40552226'},
#  {'address': {'building': '202',
#    'coord': [-73.9164504, 40.8341845],
#    'street': 'East  167 Street',
#    'zipcode': '10456'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1355961600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1343779200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1331596800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Lucky House Restaurant',
#   'restaurant_id': '40571587'},
#  {'address': {'building': '1474',
#    'coord': [-73.88122729999999, 40.8281391],
#    'street': 'Westchester Avenue',
#    'zipcode': '10472'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1419379200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389571200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 9}],
#   'name': 'New Wah Kitchen',
#   'restaurant_id': '40573101'},
#  {'address': {'building': '1702',
#    'coord': [-73.9137269, 40.8482958],
#    'street': 'Grand Avenue',
#    'zipcode': '10453'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1397606400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1365552000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1331683200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1316649600000}, 'grade': 'B', 'score': 17}],
#   'name': 'New Hing Restaurant',
#   'restaurant_id': '40701165'},
#  {'address': {'building': '1811',
#    'coord': [-73.8518311, 40.8504655],
#    'street': 'Williamsbridge Road',
#    'zipcode': '10461'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1362441600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1347408000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1334620800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1320278400000}, 'grade': 'A', 'score': 4}],
#   'name': 'Hong Kong Restaurant',
#   'restaurant_id': '40765358'},
#  {'address': {'building': '796',
#    'coord': [-73.91637759999999, 40.8226814],
#    'street': 'Courtlandt Avenue',
#    'zipcode': '10451'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1408060800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1377561600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1362528000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1344902400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1332288000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1319414400000}, 'grade': 'A', 'score': 12}],
#   'name': "Kristy'S Restaurant",
#   'restaurant_id': '40804049'},
#  {'address': {'building': '1634',
#    'coord': [-73.8306577, 40.8450232],
#    'street': 'Crosby Avenue',
#    'zipcode': '10461'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1407456000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1374537600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1355443200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1340582400000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1317600000000}, 'grade': 'A', 'score': 8}],
#   'name': 'East Dynasty',
#   'restaurant_id': '40827529'},
#  {'address': {'building': '2461',
#    'coord': [-73.9041182, 40.8644648],
#    'street': 'University Avenue',
#    'zipcode': '10468'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1397088000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1364342400000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1351123200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1349913600000}, 'grade': 'P', 'score': 2},
#    {'date': {'$date': 1320105600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1303257600000}, 'grade': 'B', 'score': 17}],
#   'name': 'Lin Home Chinese Restaura',
#   'restaurant_id': '40842437'},
#  {'address': {'building': '70',
#    'coord': [-73.9066601, 40.8592187],
#    'street': 'West  183 Street',
#    'zipcode': '10453'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1417392000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1404259200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1390435200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1374624000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1358121600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1342656000000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1324425600000}, 'grade': 'B', 'score': 14}],
#   'name': 'Peacock Restaurant',
#   'restaurant_id': '40849313'},
#  {'address': {'building': '317',
#    'coord': [-73.909629, 40.837446],
#    'street': 'East 170 Street',
#    'zipcode': '10456'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1417564800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1398470400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1384819200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1367798400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1347321600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1334620800000}, 'grade': 'A', 'score': 13}],
#   'name': "Lin'S Garden",
#   'restaurant_id': '40857406'},
#  {'address': {'building': '3906',
#    'coord': [-73.8612466, 40.8858379],
#    'street': 'White Plains Road',
#    'zipcode': '10466'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1399852800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1381104000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1349308800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1317772800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1309392000000}, 'grade': 'A', 'score': 7}],
#   'name': 'New Rainbow Restaurant',
#   'restaurant_id': '40899178'},
#  {'address': {'building': '1236',
#    'coord': [-73.8893654, 40.81376179999999],
#    'street': '238 Spofford Ave',
#    'zipcode': '10474'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1388361600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1339459200000}, 'grade': 'B', 'score': 15}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'address': {'building': '277',
#    'coord': [-73.8941893, 40.8634684],
#    'street': 'East Kingsbridge Road',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1363651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'address': {'building': '2459',
#    'coord': [-73.8929629, 40.8601605],
#    'street': 'Webster Avenue',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1419292800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1389052800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1356652800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1342569600000}, 'grade': 'A', 'score': 13}],
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'address': {'building': '2102',
#    'coord': [-73.82609699999999, 40.8687177],
#    'street': 'Bartow Ave',
#    'zipcode': '10475'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1407110400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1392940800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1369872000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12}],
#   'name': 'Dragon City',
#   'restaurant_id': '40529203'},
#  {'address': {'building': '3511',
#    'coord': [-73.9100876, 40.8860444],
#    'street': 'Johnson Avenue',
#    'zipcode': '10463'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1404259200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1383696000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1364515200000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1340150400000}, 'grade': 'B', 'score': 27}],
#   'name': 'Hunan Balcony',
#   'restaurant_id': '40551996'},
#  {'address': {'building': '732',
#    'coord': [-73.883128, 40.85353],
#    'street': 'East  187 Street',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1415318400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400112000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1384732800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1370822400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1347840000000}, 'grade': 'B', 'score': 19}],
#   'name': 'Great Wall Restaurant',
#   'restaurant_id': '40552226'},
#  {'address': {'building': '202',
#    'coord': [-73.9164504, 40.8341845],
#    'street': 'East  167 Street',
#    'zipcode': '10456'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1355961600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1343779200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1331596800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Lucky House Restaurant',
#   'restaurant_id': '40571587'},
#  {'address': {'building': '1474',
#    'coord': [-73.88122729999999, 40.8281391],
#    'street': 'Westchester Avenue',
#    'zipcode': '10472'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1419379200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389571200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 9}],
#   'name': 'New Wah Kitchen',
#   'restaurant_id': '40573101'},
#  {'address': {'building': '1702',
#    'coord': [-73.9137269, 40.8482958],
#    'street': 'Grand Avenue',
#    'zipcode': '10453'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1397606400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1365552000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1331683200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1316649600000}, 'grade': 'B', 'score': 17}],
#   'name': 'New Hing Restaurant',
#   'restaurant_id': '40701165'},
#  {'address': {'building': '1811',
#    'coord': [-73.8518311, 40.8504655],
#    'street': 'Williamsbridge Road',
#    'zipcode': '10461'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1362441600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1347408000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1334620800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1320278400000}, 'grade': 'A', 'score': 4}],
#   'name': 'Hong Kong Restaurant',
#   'restaurant_id': '40765358'},
#  {'address': {'building': '796',
#    'coord': [-73.91637759999999, 40.8226814],
#    'street': 'Courtlandt Avenue',
#    'zipcode': '10451'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1408060800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1377561600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1362528000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1344902400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1332288000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1319414400000}, 'grade': 'A', 'score': 12}],
#   'name': "Kristy'S Restaurant",
#   'restaurant_id': '40804049'},
#  {'address': {'building': '1634',
#    'coord': [-73.8306577, 40.8450232],
#    'street': 'Crosby Avenue',
#    'zipcode': '10461'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1407456000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1374537600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1355443200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1340582400000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1317600000000}, 'grade': 'A', 'score': 8}],
#   'name': 'East Dynasty',
#   'restaurant_id': '40827529'},
#  {'address': {'building': '2461',
#    'coord': [-73.9041182, 40.8644648],
#    'street': 'University Avenue',
#    'zipcode': '10468'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1397088000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1364342400000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1351123200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1349913600000}, 'grade': 'P', 'score': 2},
#    {'date': {'$date': 1320105600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1303257600000}, 'grade': 'B', 'score': 17}],
#   'name': 'Lin Home Chinese Restaura',
#   'restaurant_id': '40842437'},
#  {'address': {'building': '70',
#    'coord': [-73.9066601, 40.8592187],
#    'street': 'West  183 Street',
#    'zipcode': '10453'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1417392000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1404259200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1390435200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1374624000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1358121600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1342656000000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1324425600000}, 'grade': 'B', 'score': 14}],
#   'name': 'Peacock Restaurant',
#   'restaurant_id': '40849313'},
#  {'address': {'building': '317',
#    'coord': [-73.909629, 40.837446],
#    'street': 'East 170 Street',
#    'zipcode': '10456'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1417564800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1398470400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1384819200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1367798400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1347321600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1334620800000}, 'grade': 'A', 'score': 13}],
#   'name': "Lin'S Garden",
#   'restaurant_id': '40857406'},
#  {'address': {'building': '3906',
#    'coord': [-73.8612466, 40.8858379],
#    'street': 'White Plains Road',
#    'zipcode': '10466'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1399852800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1381104000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1349308800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1317772800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1309392000000}, 'grade': 'A', 'score': 7}],
#   'name': 'New Rainbow Restaurant',
#   'restaurant_id': '40899178'}]

# %% [markdown]
# ### 9. Devolver ID del restaurante, nombre, distrito y la cocina para aquellos restaurantes que pertenecen al distrito de Staten Island o Queens o Bronx o Brooklyn

# %%
proyeccion = {"_id":1, "name":1, "borough":1, "cuisine":1}

filtro = {"$or": [{"borough": "Staten Island"},{"borough": "Queen"}, {"borough": "Bronx"}, {"borough": "Brooklyn"} ]}

list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'_id': ObjectId('67349b13ace753fad167f78b'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f78c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f78e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Riviera Caterer'},
#  {'_id': ObjectId('67349b13ace753fad167f791'),
#   'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Island'},
#  {'_id': ObjectId('67349b13ace753fad167f792'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': "Wilken'S Fine Food"},
#  {'_id': ObjectId('67349b13ace753fad167f793'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Regina Caterers'},
#  {'_id': ObjectId('67349b13ace753fad167f794'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Taste The Tropics Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f795'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia'},
#  {'_id': ObjectId('67349b13ace753fad167f796'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'C & C Catering Service'},
#  {'_id': ObjectId('67349b13ace753fad167f797'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'May May Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167f799'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Seuda Foods'},
#  {'_id': ObjectId('67349b13ace753fad167f79a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f79c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': 'Nordic Delicacies'},
#  {'_id': ObjectId('67349b13ace753fad167f79e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Movable Feast'},
#  {'_id': ObjectId('67349b13ace753fad167f7a5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f7a8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': "Shashemene Int'L Restaura"},
#  {'_id': ObjectId('67349b13ace753fad167f7aa'),
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f7ab'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167f7ac'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mejlander & Mulgannon'},
#  {'_id': ObjectId('67349b13ace753fad167f7ae'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'_id': ObjectId('67349b13ace753fad167f7b2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagels N Buns'},
#  {'_id': ObjectId('67349b13ace753fad167f7b8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Sonny'S Heros"},
#  {'_id': ObjectId('67349b13ace753fad167f7b9'),
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f7ba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Golden Pavillion'},
#  {'_id': ObjectId('67349b13ace753fad167f7bd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Bagel Hole'},
#  {'_id': ObjectId('67349b13ace753fad167f7bf'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'Plaza Bagels & Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f7c0'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'_id': ObjectId('67349b13ace753fad167f7c1'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'B & M Hot Bagel & Grocery'},
#  {'_id': ObjectId('67349b13ace753fad167f7c3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Philadelhia Grille Express'},
#  {'_id': ObjectId('67349b13ace753fad167f7c4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': 'Peter Luger Steakhouse'},
#  {'_id': ObjectId('67349b13ace753fad167f7c8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7cb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': 'Polish National Home'},
#  {'_id': ObjectId('67349b13ace753fad167f7d5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Junior'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7d6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Great Kills Yacht Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7d8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Towne Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7de'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Melody Lanes'},
#  {'_id': ObjectId('67349b13ace753fad167f7e0'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx'},
#  {'_id': ObjectId('67349b13ace753fad167f7e2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Crystal Room'},
#  {'_id': ObjectId('67349b13ace753fad167f7e3'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Labetti'S Post # 2159"},
#  {'_id': ObjectId('67349b13ace753fad167f7e4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Shell Lanes'},
#  {'_id': ObjectId('67349b13ace753fad167f7e7'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'South Shore Swimming Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7e9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': 'Nostrand Donut Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f7f0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'New Corner'},
#  {'_id': ObjectId('67349b13ace753fad167f7f5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Joe & Pat'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f7f7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Palace Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7f8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f7fb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Reben Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f7ff'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'J&V Famous Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f802'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Joyce'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f805'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Gargiulo'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f80b'),
#   'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f813'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Fifth Avenue Bingo'},
#  {'_id': ObjectId('67349b13ace753fad167f814'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Denino'S Pizzeria Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f815'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Michael'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f81c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Three Star Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f821'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Roll-N-Roaster'},
#  {'_id': ObjectId('67349b13ace753fad167f823'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Brennan & Carr'},
#  {'_id': ObjectId('67349b13ace753fad167f824'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl'},
#  {'_id': ObjectId('67349b13ace753fad167f82a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Fascati'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f82c'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Li Greci'S Staaten Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f82e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Tamaqua'},
#  {'_id': ObjectId('67349b13ace753fad167f82f'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime'},
#  {'_id': ObjectId('67349b13ace753fad167f831'),
#   'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167f834'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Richmond County Country Club'},
#  {'_id': ObjectId('67349b13ace753fad167f836'),
#   'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop"},
#  {'_id': ObjectId('67349b13ace753fad167f837'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Soul Food',
#   'name': "Mitchell'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f83a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Da Vinci Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f83c'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray'},
#  {'_id': ObjectId('67349b13ace753fad167f83d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'New Floridian Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f83f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Narrows Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f84d'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Buddy'S Wonder Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f852'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Ni-Ni'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167f85a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f85b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Greek',
#   'name': 'El Greco Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f85f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Lb Spumoni Gardens'},
#  {'_id': ObjectId('67349b13ace753fad167f861'),
#   'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest"},
#  {'_id': ObjectId('67349b13ace753fad167f862'),
#   'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f863'),
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace'},
#  {'_id': ObjectId('67349b13ace753fad167f864'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone'},
#  {'_id': ObjectId('67349b13ace753fad167f865'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond'},
#  {'_id': ObjectId('67349b13ace753fad167f866'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)'},
#  {'_id': ObjectId('67349b13ace753fad167f867'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Roadhouse Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f86a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Mill Basin Kosher Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f86d'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Colonnade Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f874'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Frost Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f877'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Denny'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f87a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'New Parkway Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f886'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f888'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Hytes Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f88a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Jody'S Club"},
#  {'_id': ObjectId('67349b13ace753fad167f88e'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f892'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Armando'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f895'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f897'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Cafe Capri'},
#  {'_id': ObjectId('67349b13ace753fad167f898'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f899'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The River Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f89b'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f89c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89d'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f8a0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Ferdinando'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8a5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8aa'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill"},
#  {'_id': ObjectId('67349b13ace753fad167f8ab'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8b1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Bamonte'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8b4'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f8ba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Greenpoint Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f8bb'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8bc'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f8c8'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Perkins Family Restaurant & Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167f8ca'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8ce'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Mama Lucia'},
#  {'_id': ObjectId('67349b13ace753fad167f8d2'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Delight'},
#  {'_id': ObjectId('67349b13ace753fad167f8d6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Dairy Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f8d8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'La Palina Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8d9'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Schaffer'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f8dc'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mariner Inn'},
#  {'_id': ObjectId('67349b13ace753fad167f8de'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Exclusive Catering'},
#  {'_id': ObjectId('67349b13ace753fad167f8df'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Green House Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8e0'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8e3'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Marina Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8ea'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Veterans Of Foreign Wars Post #107 Canteen'},
#  {'_id': ObjectId('67349b13ace753fad167f8ec'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': 'Tropical House Baking Co.'},
#  {'_id': ObjectId('67349b13ace753fad167f8ee'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f8f1'),
#   'borough': 'Staten Island',
#   'cuisine': 'Chinese',
#   'name': "Chen'S Chinese"},
#  {'_id': ObjectId('67349b13ace753fad167f8f4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': 'Casa Pepe'},
#  {'_id': ObjectId('67349b13ace753fad167f8f6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Golden Dove Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f8f8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Korner Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f8f9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Henry'S End"},
#  {'_id': ObjectId('67349b13ace753fad167f8fd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Petes Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f903'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f906'),
#   'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167f907'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Bridgeview Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f90c'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f90e'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f910'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Victoria Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f913'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'El Caribe'},
#  {'_id': ObjectId('67349b13ace753fad167f916'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f91d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Turkey'S Nest Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f91e'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f927'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Maria Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f92a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Villa Fiorita'},
#  {'_id': ObjectId('67349b13ace753fad167f92b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Vegas Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f934'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "King'S Arms Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f937'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Marco Polo Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f93a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'War Memorial Ice Skating Rink'},
#  {'_id': ObjectId('67349b13ace753fad167f93b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mediterranean',
#   'name': 'Tripoli Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f942'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f944'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f945'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Sunset Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f94a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Vesuvio Restaurant & Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f955'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Red Rose'},
#  {'_id': ObjectId('67349b13ace753fad167f956'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f957'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Fiorentino Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f95f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Knights Of Baron Dekalb'},
#  {'_id': ObjectId('67349b13ace753fad167f960'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Union Hall'},
#  {'_id': ObjectId('67349b13ace753fad167f961'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Hut Of Brooklyn'},
#  {'_id': ObjectId('67349b13ace753fad167f969'),
#   'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167f971'),
#   'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North'},
#  {'_id': ObjectId('67349b13ace753fad167f975'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Rex Manor'},
#  {'_id': ObjectId('67349b13ace753fad167f976'),
#   'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos'},
#  {'_id': ObjectId('67349b13ace753fad167f978'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f97c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Japanese',
#   'name': 'Geido Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f981'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#   'name': 'Montero Bar & Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f984'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Seafood',
#   'name': "Pete'S Clam Stop"},
#  {'_id': ObjectId('67349b13ace753fad167f987'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Smiling Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f98b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Nina'S Restaurant Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f98d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Clark'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f992'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Duffy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f994'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Latourette Golf Course'},
#  {'_id': ObjectId('67349b13ace753fad167f995'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Dyker Beach Golf (Grill Room)'},
#  {'_id': ObjectId('67349b13ace753fad167f996'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': "Glenda'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f997'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "My Father'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167f998'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'name': 'Santa Fe Grill & Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f99b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f99d'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f99e'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f9a1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Fe Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9a3'),
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken"},
#  {'_id': ObjectId('67349b13ace753fad167f9a6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "O'Sullivan'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f9a8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Wagon'},
#  {'_id': ObjectId('67349b13ace753fad167f9b3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f9b5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Spanish',
#   'name': 'Real Madrid Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9b6'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Canlon'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f9b7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': "Cousin John'S Cafe And Bakery"},
#  {'_id': ObjectId('67349b13ace753fad167f9b9'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9bd'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza',
#   'name': "Pizza D'Oro"},
#  {'_id': ObjectId('67349b13ace753fad167f9be'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f9c6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'name': "Sancho'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f9c8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'name': 'India Passage Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9c9'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9ca'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': "Irene'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167f9cd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f9ce'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'J & R Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f9d3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Rocco'S Calamari"},
#  {'_id': ObjectId('67349b13ace753fad167f9d5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Grand Canyon'},
#  {'_id': ObjectId('67349b13ace753fad167f9d6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Cappuccino Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f9d7'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Carol'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167f9dd'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza',
#   'name': 'Dairy Palace'},
#  {'_id': ObjectId('67349b13ace753fad167f9de'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': '200 Fifth Avenue Restaurant & Sports Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f9e5'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor'},
#  {'_id': ObjectId('67349b13ace753fad167f9e7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Academy Restauraunt'},
#  {'_id': ObjectId('67349b13ace753fad167f9e8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Park Plaza Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9ec'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': "Hunter'S Steak & Ale House"},
#  {'_id': ObjectId('67349b13ace753fad167f9ed'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f9ee'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Dakota Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f9f0'),
#   'borough': 'Staten Island',
#   'cuisine': 'Japanese',
#   'name': 'Arirang Hibachi Steak House'},
#  {'_id': ObjectId('67349b13ace753fad167f9f1'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f9f2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Donuts',
#   'name': 'Country Donuts'},
#  {'_id': ObjectId('67349b13ace753fad167f9f4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Middle Eastern',
#   'name': "Sally & George'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167f9f6'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f9f8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Plus'},
#  {'_id': ObjectId('67349b13ace753fad167fa01'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Tina'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fa05'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Rocco'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fa08'),
#   'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl"},
#  {'_id': ObjectId('67349b13ace753fad167fa0d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa14'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa16'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa17'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Teddy'S Bar And Grill"},
#  {'_id': ObjectId('67349b13ace753fad167fa19'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Jimmy Max Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa1e'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fa20'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Nostrand Island Eatery'},
#  {'_id': ObjectId('67349b13ace753fad167fa21'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa22'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop'},
#  {'_id': ObjectId('67349b13ace753fad167fa24'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Rosebank Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167fa26'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Areo Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa27'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Green Pavilion Restaurant & Sports Lounge'},
#  {'_id': ObjectId('67349b13ace753fad167fa2e'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167fa30'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Luigi'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fa37'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place'},
#  {'_id': ObjectId('67349b13ace753fad167fa38'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Amnon Kosher Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fa39'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa3e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': "Lee'S Villa Chinese Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fa3f'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt'},
#  {'_id': ObjectId('67349b13ace753fad167fa42'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fa43'),
#   'borough': 'Staten Island',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Puttin On A Bagel'},
#  {'_id': ObjectId('67349b13ace753fad167fa46'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Brooklyn Botanic Catering Hall'},
#  {'_id': ObjectId('67349b13ace753fad167fa49'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Queen Bee'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167fa4b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa51'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Eastern European',
#   'name': "Teresa'S Resturant"},
#  {'_id': ObjectId('67349b13ace753fad167fa53'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Chadwick'S"},
#  {'_id': ObjectId('67349b13ace753fad167fa5a'),
#   'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fa60'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Royal Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fa67'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fa6a'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Rino'S"},
#  {'_id': ObjectId('67349b13ace753fad167fa6f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Giando'},
#  {'_id': ObjectId('67349b13ace753fad167fa74'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Queen'},
#  {'_id': ObjectId('67349b13ace753fad167fa80'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Villa Barone Manor'},
#  {'_id': ObjectId('67349b13ace753fad167fa82'),
#   'borough': 'Staten Island',
#   'cuisine': 'Indian',
#   'name': 'Taste Of India Ii Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa84'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Kum Kau Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167fa85'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Danny Blaine'},
#  {'_id': ObjectId('67349b13ace753fad167fa88'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Dennis' Place"},
#  {'_id': ObjectId('67349b13ace753fad167fa8b'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood'},
#  {'_id': ObjectId('67349b13ace753fad167fa8e'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Cafe Luna'},
#  {'_id': ObjectId('67349b13ace753fad167fa90'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Irish',
#   'name': "Killarney'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167fa95'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': 'A & S Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fa9d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Grotto Azzura Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167faa3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Bay Ridge Manor Catering'},
#  {'_id': ObjectId('67349b13ace753fad167faa6'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Gleason'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167faab'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Szechuan Delight Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167faae'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Collado Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fab0'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fab8'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Hillside Swimming Club'},
#  {'_id': ObjectId('67349b13ace753fad167fab9'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'La Strada Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fabd'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza',
#   'name': "Salvatore And Lloyd'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fac0'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham Seafood And Chicken'},
#  {'_id': ObjectId('67349b13ace753fad167fac4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'name': "Charle'S Corner Restaurant & Deli"},
#  {'_id': ObjectId('67349b13ace753fad167fac5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Cafe Bella Vita'},
#  {'_id': ObjectId('67349b13ace753fad167facd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Sal'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fad3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Bergen Beach Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fad9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Russian',
#   'name': 'National Restaurant & Catering'},
#  {'_id': ObjectId('67349b13ace753fad167fadd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Metrostar Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fae3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Yen Yen Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fae4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'name': "Buddy'S Burrito & Taco Bar"},
#  {'_id': ObjectId('67349b13ace753fad167fae6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Sandwiches',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167faea'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'V & S Pizzeria Of Sheapshead Bay'},
#  {'_id': ObjectId('67349b13ace753fad167faee'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Cody'S Ale House Grill"},
#  {'_id': ObjectId('67349b13ace753fad167faf0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'J.J. Bubbles'},
#  {'_id': ObjectId('67349b13ace753fad167faf2'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Faros Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167faf3'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Gun Post Lanes Snack Bar'},
#  {'_id': ObjectId('67349b13ace753fad167faf8'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Molino Rojo Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb05'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizza Ii"},
#  {'_id': ObjectId('67349b13ace753fad167fb08'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "O'Brien'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167fb09'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Salvi Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb0a'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Tibbett Diner'},
#  {'_id': ObjectId('67349b13ace753fad167fb0e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Garden Of Eat-In'},
#  {'_id': ObjectId('67349b13ace753fad167fb13'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Plate'},
#  {'_id': ObjectId('67349b13ace753fad167fb18'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Tommaso Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb19'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Frank'S Pizza Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fb1e'),
#   'borough': 'Staten Island',
#   'cuisine': 'Chinese',
#   'name': 'Island Taste'},
#  {'_id': ObjectId('67349b13ace753fad167fb20'),
#   'borough': 'Staten Island',
#   'cuisine': 'Chinese',
#   'name': 'Master Wok'},
#  {'_id': ObjectId('67349b13ace753fad167fb23'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'A.J. Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fb29'),
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': "Egger'S Ice Cream Parlor"},
#  {'_id': ObjectId('67349b13ace753fad167fb2a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Gino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fb2f'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'E & L Bakery & Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167fb31'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wembley Athletic Club'},
#  {'_id': ObjectId('67349b13ace753fad167fb32'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cullen'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167fb34'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Las Isla Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb36'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Tuscany Grill'},
#  {'_id': ObjectId('67349b13ace753fad167fb42'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria & Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fb4a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'My Three Sons Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb4b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chicken',
#   'name': 'Chicken Delicious'},
#  {'_id': ObjectId('67349b13ace753fad167fb4d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Mike'S Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167fb52'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fb54'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mcdonald Avenue Diner'},
#  {'_id': ObjectId('67349b13ace753fad167fb55'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': "Mezcal'S Dos Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fb57'),
#   'borough': 'Staten Island',
#   'cuisine': 'Donuts',
#   'name': 'Country Donuts'},
#  {'_id': ObjectId('67349b13ace753fad167fb58'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Frank'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167fb5a'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fb5e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Caruso Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb5f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Indonesian',
#   'name': 'Java Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fb62'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Nosh'},
#  {'_id': ObjectId('67349b13ace753fad167fb68'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Golden Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fb69'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fb6a'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fb70'),
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chick-N-Ribs'},
#  {'_id': ObjectId('67349b13ace753fad167fb77'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Gennaro'S Rest & Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fb80'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fb82'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': "Christina'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fb86'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Royal King'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fb88'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Mr. Phil'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fb8c'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pugsley Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fb98'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Angelo'S Pizzeria/Mimmo'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fb9a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Excelsior Catering'},
#  {'_id': ObjectId('67349b13ace753fad167fba2'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fba4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Sugar Hill Restaurant, Supper Club And Disco'},
#  {'_id': ObjectId('67349b13ace753fad167fba6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': 'Arirang Hibachi Steakhouse'},
#  {'_id': ObjectId('67349b13ace753fad167fbb1'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Dominick'S Bar & Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbb3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'La Villa Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fbb4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Jentana'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fbb5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Europa Night Club'},
#  {'_id': ObjectId('67349b13ace753fad167fbb9'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fbba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Gourmet Grill'},
#  {'_id': ObjectId('67349b13ace753fad167fbc1'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Zaro'S Bread Basket"},
#  {'_id': ObjectId('67349b13ace753fad167fbc3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Caterina'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fbc7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'La Locanda Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fbd1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167fbd3'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Trattoria Romana'},
#  {'_id': ObjectId('67349b13ace753fad167fbd4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Pavillion Caterers'},
#  {'_id': ObjectId('67349b13ace753fad167fbd5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Perry'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbde'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Lechonera Criolla'},
#  {'_id': ObjectId('67349b13ace753fad167fbe0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Master Wok'},
#  {'_id': ObjectId('67349b13ace753fad167fbe4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Hanson Restaurant And Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fbe8'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Enzo Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fbe9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Knapp St Pizza Ii'},
#  {'_id': ObjectId('67349b13ace753fad167fbea'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Choy Le Chinese Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fbeb'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Joe'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fbed'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Henny'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbee'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Lolita'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbf6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mugs Ale House Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fbff'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167fc0c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Mike'S Coffee Shop"},
#  {'_id': ObjectId('67349b13ace753fad167fc13'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Noodle Pudding'},
#  {'_id': ObjectId('67349b13ace753fad167fc14'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': "Michael'S Pastry Shop"},
#  {'_id': ObjectId('67349b13ace753fad167fc15'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fc18'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'International Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fc1f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Lenny'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fc21'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': "Schick'S Manor"},
#  {'_id': ObjectId('67349b13ace753fad167fc23'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Fifth Ave Cafe /Diner'},
#  {'_id': ObjectId('67349b13ace753fad167fc24'),
#   'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Rolen Bagels'},
#  {'_id': ObjectId('67349b13ace753fad167fc25'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Villa Monte Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fc2a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Circle'S Grill"},
#  {'_id': ObjectId('67349b13ace753fad167fc2c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': 'Lomzymianka Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fc2d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese/Japanese',
#   'name': 'China Glatt'},
#  {'_id': ObjectId('67349b13ace753fad167fc33'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
# ...
#   'name': 'Blue Diner'},
#  {'_id': ObjectId('67349b13ace753fad1680324'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Iona'S Bar"},
#  {'_id': ObjectId('67349b13ace753fad168032a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': 'Paneantico Bakery'},
#  {'_id': ObjectId('67349b13ace753fad168033f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'name': 'American Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad1680343'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Applebee'S Neighborhood Grill & Bar"},
#  {'_id': ObjectId('67349b13ace753fad1680345'),
#   'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Bally Total Fitness'},
#  {'_id': ObjectId('67349b13ace753fad1680346'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad1680348'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Albany Manor'},
#  {'_id': ObjectId('67349b13ace753fad168034a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Elegante Pizza'},
#  {'_id': ObjectId('67349b13ace753fad168034d'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Morris Park Pizza'},
#  {'_id': ObjectId('67349b13ace753fad168034e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'name': 'Istanbul Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad1680351'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Circle Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad1680356'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'name': 'Taj Mahal Indian Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad1680357'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Best Deli Cafe'},
#  {'_id': ObjectId('67349b13ace753fad168035c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': 'Bergen Bagels'},
#  {'_id': ObjectId('67349b13ace753fad168035d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Bahia Restaurant & Cafe'},
#  {'_id': ObjectId('67349b13ace753fad168035f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Angry Wades'},
#  {'_id': ObjectId('67349b13ace753fad168036c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Nino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad168036d'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bella Napoli'},
#  {'_id': ObjectId('67349b13ace753fad168036e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Luigi'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad168036f'),
#   'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Astral Fitness & Wellness'},
#  {'_id': ObjectId('67349b13ace753fad1680373'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Barnes & Noble Cafe'},
#  {'_id': ObjectId('67349b13ace753fad168037c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad168037e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'name': 'Memo Shish Kebab'},
#  {'_id': ObjectId('67349b13ace753fad1680381'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad1680383'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Golden Krust Caribbean Bakery & Grill'},
#  {'_id': ObjectId('67349b13ace753fad1680385'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'name': 'Bliss Bakery & Cafe'},
#  {'_id': ObjectId('67349b13ace753fad1680386'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Golden Krust Caribbean Bakery & Grill'},
#  {'_id': ObjectId('67349b13ace753fad1680387'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Brazen Head'},
#  {'_id': ObjectId('67349b13ace753fad168038c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Chadash Falafel & Pizza'},
#  {'_id': ObjectId('67349b13ace753fad168038f'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hong Kong Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad1680390'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Footprints Cafe'},
#  {'_id': ObjectId('67349b13ace753fad1680392'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad'},
#  {'_id': ObjectId('67349b13ace753fad1680395'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': 'El Loco Burrito'},
#  {'_id': ObjectId('67349b13ace753fad1680398'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Alices'},
#  {'_id': ObjectId('67349b13ace753fad168039b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chicken',
#   'name': 'Popeyes Chicken & Biscuits'},
#  {'_id': ObjectId('67349b13ace753fad168039c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Charles Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad168039d'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad168039e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Convivium Osteria'},
#  {'_id': ObjectId('67349b13ace753fad16803a2'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'name': 'Cindy Restaurant Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad16803b6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Boston Market'},
#  {'_id': ObjectId('67349b13ace753fad16803b7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Boston Market'},
#  {'_id': ObjectId('67349b13ace753fad16803b9'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Boston Market'},
#  {'_id': ObjectId('67349b13ace753fad16803ba'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Boston Market'},
#  {'_id': ObjectId('67349b13ace753fad16803c0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Kelly'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad16803cc'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Bay Pizzeria Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16803d1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Boston Jerk-City Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16803d2'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Mr. Wonton'},
#  {'_id': ObjectId('67349b13ace753fad16803d5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza',
#   'name': 'La Piazza Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16803d7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Baskin Robbins'},
#  {'_id': ObjectId('67349b13ace753fad16803d9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Chock Full O' Nuts"},
#  {'_id': ObjectId('67349b13ace753fad16803da'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Union Pool'},
#  {'_id': ObjectId('67349b13ace753fad16803de'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Dancing Crane Cafe (Bx Zoo)'},
#  {'_id': ObjectId('67349b13ace753fad16803df'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad16803e0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad16803e1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Rose Water'},
#  {'_id': ObjectId('67349b13ace753fad16803e3'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad16803e7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Russian',
#   'name': 'Anyway Cafe Bar'},
#  {'_id': ObjectId('67349b13ace753fad16803e8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Plymouth Cafe'},
#  {'_id': ObjectId('67349b13ace753fad16803e9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'D & P Restaurant & Cocktail'},
#  {'_id': ObjectId('67349b13ace753fad16803f6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Metropolitan'},
#  {'_id': ObjectId('67349b13ace753fad16803f8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Section 5 Pizza Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16803fb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': 'One Deli Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16803fe'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'name': 'Joya'},
#  {'_id': ObjectId('67349b13ace753fad1680402'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Seafood',
#   'name': 'Surf Bar'},
#  {'_id': ObjectId('67349b13ace753fad1680404'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Curves Gentleman'S Club"},
#  {'_id': ObjectId('67349b13ace753fad1680407'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Panda Restuarant'},
#  {'_id': ObjectId('67349b13ace753fad1680409'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Step In Restaurant & Lounge'},
#  {'_id': ObjectId('67349b13ace753fad168040b'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad168040e'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad1680416'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Manor House Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad1680419'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Seafood',
#   'name': "Randazzo'S Clam Bar"},
#  {'_id': ObjectId('67349b13ace753fad168041a'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Kristy'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad168041b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': '(Lewis Drug Store) Locanda Vini E Olii'},
#  {'_id': ObjectId('67349b13ace753fad168041d'),
#   'borough': 'Staten Island',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Barnes & Noble Cafe'},
#  {'_id': ObjectId('67349b13ace753fad168041e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad1680422'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Cafe Renaissance'},
#  {'_id': ObjectId('67349b13ace753fad1680423'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Irish',
#   'name': "Ginger'S Bar"},
#  {'_id': ObjectId('67349b13ace753fad1680427'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Richmond County Country Club - Pool Snack Bar'},
#  {'_id': ObjectId('67349b13ace753fad1680428'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Richmond County Country Club(10Th Hole)'},
#  {'_id': ObjectId('67349b13ace753fad1680429'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Richmond County Country Club'},
#  {'_id': ObjectId('67349b13ace753fad168042a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': 'Fei Teng Bakery'},
#  {'_id': ObjectId('67349b13ace753fad168042b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'French',
#   'name': 'Bar Tabac'},
#  {'_id': ObjectId('67349b13ace753fad168042c'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Bermay Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad168042f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': '9024/Catering By Michael Schick Inc.'},
#  {'_id': ObjectId('67349b13ace753fad1680430'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Golden Krust Caribbean Bakery & Grill'},
#  {'_id': ObjectId('67349b13ace753fad1680431'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'La Sorrentina Pizzeria Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad1680433'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad1680439'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'San German Cuchifrito'},
#  {'_id': ObjectId('67349b13ace753fad168043f'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'J & J Restaurant & Cuchifritos'},
#  {'_id': ObjectId('67349b13ace753fad168044e'),
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad168044f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Bad Boys Pizza'},
#  {'_id': ObjectId('67349b13ace753fad1680453'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Japanese',
#   'name': 'Iron Chef House'},
#  {'_id': ObjectId('67349b13ace753fad1680459'),
#   'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Boulevard Tavern'},
#  {'_id': ObjectId('67349b13ace753fad168045c'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Shore Haven Diner'},
#  {'_id': ObjectId('67349b13ace753fad168045d'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Dock Street Bar & Grill'},
#  {'_id': ObjectId('67349b13ace753fad168045f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'English',
#   'name': 'The Park Slope Chipshop'},
#  {'_id': ObjectId('67349b13ace753fad1680466'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad1680467'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad168046d'),
#   'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': "Jake'S Steakhouse"},
#  {'_id': ObjectId('67349b13ace753fad1680470'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'The Aurora Pizza Caffe'},
#  {'_id': ObjectId('67349b13ace753fad1680473'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad1680474'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Ua Court Street #12'},
#  {'_id': ObjectId('67349b13ace753fad1680476'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Columbus House'},
#  {'_id': ObjectId('67349b13ace753fad168047c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Homestretch Bar'},
#  {'_id': ObjectId('67349b13ace753fad168047d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Manny'S Cafe Family Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad1680481'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Madison'S"},
#  {'_id': ObjectId('67349b13ace753fad168048b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Trinidad Golden Place'},
#  {'_id': ObjectId('67349b13ace753fad168048c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Front Street Pizza'},
#  {'_id': ObjectId('67349b13ace753fad1680494'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'East Dynasty'},
#  {'_id': ObjectId('67349b13ace753fad1680495'),
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad1680499'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad168049d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': "Pat'S Palm Tree Inn"},
#  {'_id': ObjectId('67349b13ace753fad168049f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Blue Ribbon Brasserie'},
#  {'_id': ObjectId('67349b13ace753fad16804a3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': "Errol'S Bakery"},
#  {'_id': ObjectId('67349b13ace753fad16804aa'),
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'Ebe Ye Yie African Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16804ac'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Yb Food Market'},
#  {'_id': ObjectId('67349b13ace753fad16804af'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Bull Shots'},
#  {'_id': ObjectId('67349b13ace753fad16804b8'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Malecon Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad16804c3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Concession # 110'},
#  ...]

# %% [markdown]
# ### 10. Devolver ID del restaurante, nombre, distrito y la cocina de aquellos restaurantes que lograron una puntuación que no supere los 10

# %%
proyeccion = {"_id":1, "name":1, "borough":1, "cuisine":1}
filtro = {"grades.score":{"$lt":10}}

list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'_id': ObjectId('67349b13ace753fad167f78b'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f78c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f78d'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': 'Dj Reynolds Pub And Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f78e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Riviera Caterer'},
#  {'_id': ObjectId('67349b13ace753fad167f790'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Brunos On The Boulevard'},
#  {'_id': ObjectId('67349b13ace753fad167f791'),
#   'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Island'},
#  {'_id': ObjectId('67349b13ace753fad167f792'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': "Wilken'S Fine Food"},
#  {'_id': ObjectId('67349b13ace753fad167f793'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Regina Caterers'},
#  {'_id': ObjectId('67349b13ace753fad167f794'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Taste The Tropics Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f795'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia'},
#  {'_id': ObjectId('67349b13ace753fad167f796'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'C & C Catering Service'},
#  {'_id': ObjectId('67349b13ace753fad167f797'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'May May Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167f798'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': '1 East 66Th Street Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167f799'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Seuda Foods'},
#  {'_id': ObjectId('67349b13ace753fad167f79a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f79b'),
#   'borough': 'Queens',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f79c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': 'Nordic Delicacies'},
#  {'_id': ObjectId('67349b13ace753fad167f79d'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Glorious Food'},
#  {'_id': ObjectId('67349b13ace753fad167f79e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Movable Feast'},
#  {'_id': ObjectId('67349b13ace753fad167f79f'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': "Sal'S Deli"},
#  {'_id': ObjectId('67349b13ace753fad167f7a0'),
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'name': "Bully'S Deli"},
#  {'_id': ObjectId('67349b13ace753fad167f7a1'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': "Steve Chu'S Deli & Grocery"},
#  {'_id': ObjectId('67349b13ace753fad167f7a2'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'name': "Harriet'S Kitchen"},
#  {'_id': ObjectId('67349b13ace753fad167f7a3'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'P & S Deli Grocery'},
#  {'_id': ObjectId('67349b13ace753fad167f7a4'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Angelika Film Center'},
#  {'_id': ObjectId('67349b13ace753fad167f7a5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f7a6'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'Ho Mei Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7a7'),
#   'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'name': 'The Country Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7a8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': "Shashemene Int'L Restaura"},
#  {'_id': ObjectId('67349b13ace753fad167f7a9'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Downtown Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f7aa'),
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f7ab'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167f7ac'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mejlander & Mulgannon'},
#  {'_id': ObjectId('67349b13ace753fad167f7ad'),
#   'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'name': "Olive'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7ae'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'_id': ObjectId('67349b13ace753fad167f7af'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Cafe Metro'},
#  {'_id': ObjectId('67349b13ace753fad167f7b0'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': "Tony'S Deli"},
#  {'_id': ObjectId('67349b13ace753fad167f7b1'),
#   'borough': 'Manhattan',
#   'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#   'name': 'Lexler Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f7b2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagels N Buns'},
#  {'_id': ObjectId('67349b13ace753fad167f7b4'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Snack Time Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f7b5'),
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'name': "Lorenzo & Maria'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7b6'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f7b7'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Berkely'},
#  {'_id': ObjectId('67349b13ace753fad167f7b8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Sonny'S Heros"},
#  {'_id': ObjectId('67349b13ace753fad167f7b9'),
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f7ba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Golden Pavillion'},
#  {'_id': ObjectId('67349b13ace753fad167f7bb'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f7bc'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Spoon Bread Catering'},
#  {'_id': ObjectId('67349b13ace753fad167f7bd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Bagel Hole'},
#  {'_id': ObjectId('67349b13ace753fad167f7be'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Terminal Cafe/Yankee Clipper'},
#  {'_id': ObjectId('67349b13ace753fad167f7bf'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'Plaza Bagels & Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f7c1'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'B & M Hot Bagel & Grocery'},
#  {'_id': ObjectId('67349b13ace753fad167f7c2'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'name': 'Texas Rotisserie'},
#  {'_id': ObjectId('67349b13ace753fad167f7c3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Philadelhia Grille Express'},
#  {'_id': ObjectId('67349b13ace753fad167f7c4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': 'Peter Luger Steakhouse'},
#  {'_id': ObjectId('67349b13ace753fad167f7c5'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Metropolitan Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7c6'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Palm Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7c8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7c9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Isle Of Capri Resturant'},
#  {'_id': ObjectId('67349b13ace753fad167f7ca'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Old Town Bar & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7cb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': 'Polish National Home'},
#  {'_id': ObjectId('67349b13ace753fad167f7cc'),
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Seville Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7cd'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Criminal Court Bldg Cafeteria'},
#  {'_id': ObjectId('67349b13ace753fad167f7ce'),
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'name': 'Gottscheer Hall'},
#  {'_id': ObjectId('67349b13ace753fad167f7cf'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Nyac Main Dining Room'},
#  {'_id': ObjectId('67349b13ace753fad167f7d1'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Ben-Best Deli & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7d2'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Cafe Atelier (Art Students League)'},
#  {'_id': ObjectId('67349b13ace753fad167f7d3'),
#   'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'name': "Donohue'S Steak House"},
#  {'_id': ObjectId('67349b13ace753fad167f7d4'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'Tout Va Bien'},
#  {'_id': ObjectId('67349b13ace753fad167f7d5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Junior'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7d6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Great Kills Yacht Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7d8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Towne Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7d9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'name': 'Dining Room'},
#  {'_id': ObjectId('67349b13ace753fad167f7da'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Old Homestead'},
#  {'_id': ObjectId('67349b13ace753fad167f7db'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'New Park Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7dc'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Douglaston Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7dd'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Serendipity 3'},
#  {'_id': ObjectId('67349b13ace753fad167f7df'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Rizzo'S Fine Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f7e0'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx'},
#  {'_id': ObjectId('67349b13ace753fad167f7e1'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'White Horse Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f7e2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Crystal Room'},
#  {'_id': ObjectId('67349b13ace753fad167f7e3'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Labetti'S Post # 2159"},
#  {'_id': ObjectId('67349b13ace753fad167f7e4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Shell Lanes'},
#  {'_id': ObjectId('67349b13ace753fad167f7e5'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': "Mcsorley'S Old Ale House"},
#  {'_id': ObjectId('67349b13ace753fad167f7e6'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Forlinis Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7e7'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'South Shore Swimming Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7e8'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Corner Bistro'},
#  {'_id': ObjectId('67349b13ace753fad167f7e9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': 'Nostrand Donut Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f7ea'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': "Dorrian'S Red Hand Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f7eb'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'La Grenouille'},
#  {'_id': ObjectId('67349b13ace753fad167f7ec'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': 'Como Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f7ed'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Keats Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7ee'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Angelo Of Mulberry St.'},
#  {'_id': ObjectId('67349b13ace753fad167f7ef'),
#   'borough': 'Manhattan',
#   'cuisine': 'Mexican',
#   'name': "Panchito'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7f0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'New Corner'},
#  {'_id': ObjectId('67349b13ace753fad167f7f1'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Princeton Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7f2'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "Arturo'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7f4'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Reynold'S Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f7f5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Joe & Pat'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f7f6'),
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'name': 'Spain Restaurant & Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f7f7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Palace Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7f8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f7f9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Donuts',
#   'name': 'Donut Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f7fb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Reben Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f7fd'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'King Yum Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7fe'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Jahn'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f7ff'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'J&V Famous Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f800'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'La Parisienne Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f801'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Joe Allen Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f804'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Barbetta Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f805'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Gargiulo'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f806'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "Patsy'S Italian Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f808'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Lavelle'S Admiral'S Club"},
#  {'_id': ObjectId('67349b13ace753fad167f809'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Neary'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f80a'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': 'New York Pizza Suprema'},
#  {'_id': ObjectId('67349b13ace753fad167f80c'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Mee Sum Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f80d'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Nancy'S Fire Side"},
#  {'_id': ObjectId('67349b13ace753fad167f80f'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Nancy Whiskey Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f810'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Blarney Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f812'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Healy'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f813'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Fifth Avenue Bingo'},
#  {'_id': ObjectId('67349b13ace753fad167f814'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Denino'S Pizzeria Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f815'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Michael'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f817'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Lenihan'S Saloon"},
#  {'_id': ObjectId('67349b13ace753fad167f818'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Emilio Iii Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f819'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': 'Killarney Rose'},
#  {'_id': ObjectId('67349b13ace753fad167f81b'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Blarney Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f81c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Three Star Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f81d'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': 'Blarney Rock'},
#  {'_id': ObjectId('67349b13ace753fad167f81e'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Dangerfield'S Night Club"},
#  {'_id': ObjectId('67349b13ace753fad167f81f'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Desmond'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f820'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Naomi Kosher Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f821'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Roll-N-Roaster'},
#  {'_id': ObjectId('67349b13ace753fad167f822'),
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'name': 'Tio Pepe'},
#  {'_id': ObjectId('67349b13ace753fad167f823'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Brennan & Carr'},
#  {'_id': ObjectId('67349b13ace753fad167f824'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl'},
#  {'_id': ObjectId('67349b13ace753fad167f825'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'Jardin De China Rest'},
#  {'_id': ObjectId('67349b13ace753fad167f827'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': 'Blarney Stone'},
#  {'_id': ObjectId('67349b13ace753fad167f828'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Shimons Kosher Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f829'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Riviera Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f82a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Fascati'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f82b'),
#   'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'name': "Baby Bo'S Burritos"},
#  {'_id': ObjectId('67349b13ace753fad167f82d'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'name': 'Shun Lee Palace Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f82e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Tamaqua'},
#  {'_id': ObjectId('67349b13ace753fad167f82f'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime'},
#  {'_id': ObjectId('67349b13ace753fad167f830'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Cara Mia'},
#  {'_id': ObjectId('67349b13ace753fad167f831'),
#   'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167f832'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Maloney'S Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f833'),
#   'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'name': 'La Fusta Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f835'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Little Brown Jug'},
#  {'_id': ObjectId('67349b13ace753fad167f836'),
#   'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop"},
#  {'_id': ObjectId('67349b13ace753fad167f837'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Soul Food',
#   'name': "Mitchell'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f838'),
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'name': 'El Charro Espanol'},
#  {'_id': ObjectId('67349b13ace753fad167f839'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Finnegan'S Wake"},
#  {'_id': ObjectId('67349b13ace753fad167f83b'),
#   'borough': 'Manhattan',
#   'cuisine': 'Mexican',
#   'name': 'Mexico Lindo Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f83c'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray'},
#  {'_id': ObjectId('67349b13ace753fad167f83d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'New Floridian Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f83e'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': 'Twins Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f83f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Narrows Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f840'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Broome Street Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f841'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': "O'Hanlon'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f842'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Charlies Sports Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f843'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Jg Melon Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f845'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Emerald Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f846'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Tap Room'},
#  {'_id': ObjectId('67349b13ace753fad167f847'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Cocktail Room (Nyac)'},
#  {'_id': ObjectId('67349b13ace753fad167f848'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Flame Restaurant Coffee House'},
#  {'_id': ObjectId('67349b13ace753fad167f849'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Jackson Hole'},
#  {'_id': ObjectId('67349b13ace753fad167f84a'),
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'name': 'Zum Stammtisch'},
#  {'_id': ObjectId('67349b13ace753fad167f84b'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "John'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f84c'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Grassroot Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f84e'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'The Assembly Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f84f'),
#   'borough': 'Manhattan',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Mr Broadway Kosher Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f850'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Piccola Venezia'},
#  {'_id': ObjectId('67349b13ace753fad167f851'),
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'name': 'Malaga Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f852'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Ni-Ni'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167f853'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Capitol Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f854'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'La Bonne Soupe Bistro'},
#  {'_id': ObjectId('67349b13ace753fad167f855'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Mimis Restaurant & Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f856'),
#   'borough': 'Queens',
#   'cuisine': 'Seafood',
#   'name': "Lenny'S Clam Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f857'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Griffis Faculty Club'},
#  {'_id': ObjectId('67349b13ace753fad167f858'),
#   'borough': 'Manhattan',
#   'cuisine': 'Hotdogs',
#   'name': "Gray'S Papaya"},
#  {'_id': ObjectId('67349b13ace753fad167f859'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Dani Pizza And Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f85a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f85b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Greek',
#   'name': 'El Greco Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f85c'),
#   'borough': 'Manhattan',
#   'cuisine': 'Seafood',
#   'name': 'One If By Land Two If By Sea'},
#  {'_id': ObjectId('67349b13ace753fad167f85d'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f85e'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Fiorellos'},
#  {'_id': ObjectId('67349b13ace753fad167f85f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Lb Spumoni Gardens'},
#  {'_id': ObjectId('67349b13ace753fad167f860'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Amore Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f861'),
#   'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest"},
#  {'_id': ObjectId('67349b13ace753fad167f862'),
#   'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f863'),
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace'},
#  {'_id': ObjectId('67349b13ace753fad167f864'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone'},
#  {'_id': ObjectId('67349b13ace753fad167f865'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond'},
#  {'_id': ObjectId('67349b13ace753fad167f866'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)'},
#  {'_id': ObjectId('67349b13ace753fad167f867'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Roadhouse Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f868'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Ford Foundation Cafeteria'},
#  {'_id': ObjectId('67349b13ace753fad167f869'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Elephant & Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f86a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Mill Basin Kosher Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f86d'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Colonnade Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f86e'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Red Flame Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f86f'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Maggies Place'},
#  {'_id': ObjectId('67349b13ace753fad167f871'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Da Silvano Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f872'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Benjamin'},
#  {'_id': ObjectId('67349b13ace753fad167f873'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Jimmy'S Corner"},
#  {'_id': ObjectId('67349b13ace753fad167f874'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Frost Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f875'),
#   'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'name': "Sammy'S Steakhouse"},
#  {'_id': ObjectId('67349b13ace753fad167f876'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Il Cortile Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f877'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Denny'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f878'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Maries Crisis Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f879'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Boots & Saddle Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f87a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'New Parkway Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f87b'),
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'name': 'Cafe Riazor'},
#  {'_id': ObjectId('67349b13ace753fad167f87c'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'Raouls'},
#  {'_id': ObjectId('67349b13ace753fad167f87d'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Brook'},
#  {'_id': ObjectId('67349b13ace753fad167f87f'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "P.J.' S"},
#  {'_id': ObjectId('67349b13ace753fad167f880'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Hatsuhana Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f881'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'La Mangeoire'},
#  {'_id': ObjectId('67349b13ace753fad167f882'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': "Valentino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f883'),
#   'borough': 'Manhattan',
#   'cuisine': 'Greek',
#   'name': 'Viand Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f884'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Palm Too'},
#  {'_id': ObjectId('67349b13ace753fad167f886'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f887'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Nada-Sushi'},
#  {'_id': ObjectId('67349b13ace753fad167f889'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'Pergola Des Artistes'},
#  {'_id': ObjectId('67349b13ace753fad167f88a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Jody'S Club"},
#  {'_id': ObjectId('67349b13ace753fad167f88b'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Reif'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f88d'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "John'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f88e'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f88f'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'White Horse Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f890'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Caffe Reggio'},
#  {'_id': ObjectId('67349b13ace753fad167f892'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Armando'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f893'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Dan Tempura'},
#  {'_id': ObjectId('67349b13ace753fad167f894'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Knickerbocker Bar & Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f895'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f896'),
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Pote Espanol'},
#  {'_id': ObjectId('67349b13ace753fad167f897'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Cafe Capri'},
#  {'_id': ObjectId('67349b13ace753fad167f898'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f899'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The River Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f89a'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Mudville Saloon'},
#  {'_id': ObjectId('67349b13ace753fad167f89c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89d'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89e'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f8a0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Ferdinando'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8a1'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8a2'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Viand Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8a3'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Nectar Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f8a4'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Cupping Room'},
#  {'_id': ObjectId('67349b13ace753fad167f8a5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8a6'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Pete'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f8a7'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': "Gino'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f8a8'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': "Jim Brady'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8a9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Villa Mosconi Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8aa'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill"},
#  {'_id': ObjectId('67349b13ace753fad167f8ab'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8ac'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Reme Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8ad'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The New Amity Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8af'),
#   'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'name': 'Sparks Steak House'},
#  {'_id': ObjectId('67349b13ace753fad167f8b1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Bamonte'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8b2'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Town'},
#  {'_id': ObjectId('67349b13ace753fad167f8b3'),
#   'borough': 'Manhattan',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8b5'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8b7'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8b8'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8b9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'name': 'Mughlai Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8bb'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8bc'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f8be'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Pat'S Stationary"},
#  {'_id': ObjectId('67349b13ace753fad167f8bf'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Three Guy'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8c0'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Cucina Vivolo'},
#  {'_id': ObjectId('67349b13ace753fad167f8c1'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Players Club'},
#  {'_id': ObjectId('67349b13ace753fad167f8c2'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Divers Cove'},
#  {'_id': ObjectId('67349b13ace753fad167f8c5'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Smith & Wollensky'},
#  {'_id': ObjectId('67349b13ace753fad167f8c6'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8c7'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Olive Tree Cafe & Comedy Cellar'},
#  {'_id': ObjectId('67349b13ace753fad167f8c8'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Perkins Family Restaurant & Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167f8c9'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8ca'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8cb'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Tokubei 86'},
#  {'_id': ObjectId('67349b13ace753fad167f8ce'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Mama Lucia'},
#  {'_id': ObjectId('67349b13ace753fad167f8d0'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': 'Mariella Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f8d3'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'West Bank Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8d4'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Four Seasons'},
#  {'_id': ObjectId('67349b13ace753fad167f8d6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Dairy Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f8d7'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Zafi'S Luncheonette"},
#  {'_id': ObjectId('67349b13ace753fad167f8d9'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Schaffer'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f8da'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Ty'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8db'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': "Aunt Bella'S Rest Of Little Neck"},
#  {'_id': ObjectId('67349b13ace753fad167f8dd'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'North Shore Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f8de'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Exclusive Catering'},
#  {'_id': ObjectId('67349b13ace753fad167f8df'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Green House Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8e0'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8e1'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Water Front Crab House'},
#  {'_id': ObjectId('67349b13ace753fad167f8e2'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'La Ripaille Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8e3'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Marina Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8e4'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Don Filippo Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8e5'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8e8'),
#   'borough': 'Queens',
#   'cuisine': 'Greek',
#   'name': 'Omonia Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8ea'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Veterans Of Foreign Wars Post #107 Canteen'},
#  {'_id': ObjectId('67349b13ace753fad167f8eb'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': 'Caruso Pizza #2'},
#  {'_id': ObjectId('67349b13ace753fad167f8ec'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': 'Tropical House Baking Co.'},
#  {'_id': ObjectId('67349b13ace753fad167f8ed'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8ee'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f8ef'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Clinton Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8f0'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Shabu-Shabu 70 Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8f2'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Greek Corner'},
#  {'_id': ObjectId('67349b13ace753fad167f8f3'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Racquet & Tennis Club'},
#  {'_id': ObjectId('67349b13ace753fad167f8f5'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Astro Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8f6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Golden Dove Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f8f8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Korner Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f8f9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Henry'S End"},
#  {'_id': ObjectId('67349b13ace753fad167f8fa'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Souen Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8fb'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Villa Berulia'},
#  {'_id': ObjectId('67349b13ace753fad167f8fc'),
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Victor'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167f8fd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Petes Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8ff'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Bar 515'},
#  {'_id': ObjectId('67349b13ace753fad167f900'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': 'Ready Penny Inn'},
#  {'_id': ObjectId('67349b13ace753fad167f901'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Il Mulino'},
#  {'_id': ObjectId('67349b13ace753fad167f903'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f904'),
#   'borough': 'Manhattan',
#   'cuisine': 'Armenian',
#   'name': 'The Malt House'},
#  {'_id': ObjectId('67349b13ace753fad167f905'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'name': 'Shun Lee'},
#  {'_id': ObjectId('67349b13ace753fad167f906'),
#   'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167f907'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Bridgeview Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f908'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Burke'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f909'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Hill Tap Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f90a'),
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'name': 'Pongsri Thai Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f90c'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f90d'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "Elio'S"},
#  {'_id': ObjectId('67349b13ace753fad167f90e'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f911'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': 'Molly Wee Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f912'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'La Mediterranee Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f913'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'El Caribe'},
#  {'_id': ObjectId('67349b13ace753fad167f914'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Omen Japanese Cuisine'},
#  {'_id': ObjectId('67349b13ace753fad167f915'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f916'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f917'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Bar Vetro'},
#  {'_id': ObjectId('67349b13ace753fad167f918'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': "Rosie O'Grady Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f919'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Europa Go-Go Dancing'},
#  {'_id': ObjectId('67349b13ace753fad167f91b'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Raccoon Lodge'},
#  {'_id': ObjectId('67349b13ace753fad167f91c'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'Chez Napolean'},
#  {'_id': ObjectId('67349b13ace753fad167f91d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Turkey'S Nest Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f91e'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f91f'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'La Villa De Pizza & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f920'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Ozone Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f921'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Ponticello Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f922'),
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'name': 'Agra Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f923'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Lindy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f926'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "Gene'S Resturant"},
#  {'_id': ObjectId('67349b13ace753fad167f927'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Maria Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f928'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Cozy Soup & Burger'},
#  {'_id': ObjectId('67349b13ace753fad167f929'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Neron'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f92a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Villa Fiorita'},
#  {'_id': ObjectId('67349b13ace753fad167f92b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Vegas Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f92c'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Moms Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f92d'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Candle Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f92e'),
#   'borough': 'Manhattan',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Tevere 84'},
#  {'_id': ObjectId('67349b13ace753fad167f92f'),
#   'borough': 'Manhattan',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Haagen-Dazs'},
#  {'_id': ObjectId('67349b13ace753fad167f931'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'name': "Charlie'S Mom Chinese Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f932'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "Lusardi'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f933'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Portofino'},
#  {'_id': ObjectId('67349b13ace753fad167f934'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "King'S Arms Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f935'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Blue Note Jazz'},
#  {'_id': ObjectId('67349b13ace753fad167f936'),
#   'borough': 'Manhattan',
#   'cuisine': 'Seafood',
#   'name': 'The Water Club'},
#  {'_id': ObjectId('67349b13ace753fad167f937'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Marco Polo Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f938'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Manhattan Monster'},
#  {'_id': ObjectId('67349b13ace753fad167f939'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'American Museum Of Natural History Food Court'},
#  {'_id': ObjectId('67349b13ace753fad167f93a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'War Memorial Ice Skating Rink'},
#  {'_id': ObjectId('67349b13ace753fad167f93b'),
# ...
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Souen Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fba0'),
#   'borough': 'Manhattan',
#   'cuisine': 'Bagels/Pretzels',
#   'name': "Bagel Bob'S"},
#  {'_id': ObjectId('67349b13ace753fad167fba1'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': 'Bravo Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fba2'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fba3'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Caffe Grazie'},
#  {'_id': ObjectId('67349b13ace753fad167fba4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Sugar Hill Restaurant, Supper Club And Disco'},
#  {'_id': ObjectId('67349b13ace753fad167fba5'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Hapisgah Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fba6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': 'Arirang Hibachi Steakhouse'},
#  {'_id': ObjectId('67349b13ace753fad167fba7'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Salisbury Hotel'},
#  {'_id': ObjectId('67349b13ace753fad167fba9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'name': "Mccoy'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167fbaa'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Mustang Sally'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbab'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': "Ben'S Kosher Deli & Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbac'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Lucia Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fbad'),
#   'borough': 'Manhattan',
#   'cuisine': 'Asian',
#   'name': 'Le Colonial'},
#  {'_id': ObjectId('67349b13ace753fad167fbae'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'Credit Agricole-Cbi Executive Room'},
#  {'_id': ObjectId('67349b13ace753fad167fbaf'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Manhattan Diner'},
#  {'_id': ObjectId('67349b13ace753fad167fbb1'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Dominick'S Bar & Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbb2'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Le Mirage Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fbb3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'La Villa Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fbb4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Jentana'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fbb5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Europa Night Club'},
#  {'_id': ObjectId('67349b13ace753fad167fbb6'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': "Morton'S Steakhouse"},
#  {'_id': ObjectId('67349b13ace753fad167fbb7'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Usagi'},
#  {'_id': ObjectId('67349b13ace753fad167fbb8'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'The Mercury Lounge'},
#  {'_id': ObjectId('67349b13ace753fad167fbb9'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fbba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Gourmet Grill'},
#  {'_id': ObjectId('67349b13ace753fad167fbbc'),
#   'borough': 'Queens',
#   'cuisine': 'Caribbean',
#   'name': 'Bamboo Garden'},
#  {'_id': ObjectId('67349b13ace753fad167fbbd'),
#   'borough': 'Manhattan',
#   'cuisine': 'Barbecue',
#   'name': "Virgil'S Bbq"},
#  {'_id': ObjectId('67349b13ace753fad167fbbe'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Pyramid'},
#  {'_id': ObjectId('67349b13ace753fad167fbbf'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Toad Hall'},
#  {'_id': ObjectId('67349b13ace753fad167fbc0'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Olympia'},
#  {'_id': ObjectId('67349b13ace753fad167fbc1'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Zaro'S Bread Basket"},
#  {'_id': ObjectId('67349b13ace753fad167fbc2'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Landmark Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167fbc3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Caterina'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fbc4'),
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'name': 'Ben Ash Delicatessen'},
#  {'_id': ObjectId('67349b13ace753fad167fbc5'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Pax Wholesome Foods'},
#  {'_id': ObjectId('67349b13ace753fad167fbc6'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Mikes Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fbc7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'La Locanda Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fbc8'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Paddy Quinns'},
#  {'_id': ObjectId('67349b13ace753fad167fbc9'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Cj Sullivan'S"},
#  {'_id': ObjectId('67349b13ace753fad167fbca'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'La Gioconda'},
#  {'_id': ObjectId('67349b13ace753fad167fbcb'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fbcc'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167fbcd'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Weiss Cafe Rockefeller University'},
#  {'_id': ObjectId('67349b13ace753fad167fbce'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Home Deli & Catering'},
#  {'_id': ObjectId('67349b13ace753fad167fbd0'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Nick'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fbd1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167fbd2'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'name': 'Phoenix Garden'},
#  {'_id': ObjectId('67349b13ace753fad167fbd4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Pavillion Caterers'},
#  {'_id': ObjectId('67349b13ace753fad167fbd5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Perry'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbd6'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'San Martin'},
#  {'_id': ObjectId('67349b13ace753fad167fbd7'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Tom And Jerry Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fbd8'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167fbd9'),
#   'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'name': 'Dinastia China'},
#  {'_id': ObjectId('67349b13ace753fad167fbda'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Dyckman Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fbdb'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': "Joseph'S Ristorante"},
#  {'_id': ObjectId('67349b13ace753fad167fbdc'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'World Cup Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fbdd'),
#   'borough': 'Manhattan',
#   'cuisine': 'Mexican',
#   'name': "Blockhead'S Burritos"},
#  {'_id': ObjectId('67349b13ace753fad167fbde'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Lechonera Criolla'},
#  {'_id': ObjectId('67349b13ace753fad167fbdf'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Cafe 75 Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fbe0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Master Wok'},
#  {'_id': ObjectId('67349b13ace753fad167fbe1'),
#   'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Caffee Express'},
#  {'_id': ObjectId('67349b13ace753fad167fbe2'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Doc Holidays'},
#  {'_id': ObjectId('67349b13ace753fad167fbe3'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Famous Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fbe4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Hanson Restaurant And Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167fbe5'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Vixens'},
#  {'_id': ObjectId('67349b13ace753fad167fbe6'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167fbe9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Knapp St Pizza Ii'},
#  {'_id': ObjectId('67349b13ace753fad167fbea'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Choy Le Chinese Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fbeb'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Joe'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fbec'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Mumbles'},
#  {'_id': ObjectId('67349b13ace753fad167fbed'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Henny'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbee'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Lolita'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fbf0'),
#   'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'name': 'Candle Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fbf1'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': '9Th Ave Saloon'},
#  {'_id': ObjectId('67349b13ace753fad167fbf2'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Europa Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fbf3'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Sale & Pepe'},
#  {'_id': ObjectId('67349b13ace753fad167fbf4'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167fbf5'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Rockefeller U/Abby Bldg'},
#  {'_id': ObjectId('67349b13ace753fad167fbf6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mugs Ale House Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fbf7'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Gigino Trattoria'},
#  {'_id': ObjectId('67349b13ace753fad167fbf8'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Sony Music Employee Cafeteria'},
#  {'_id': ObjectId('67349b13ace753fad167fbf9'),
#   'borough': 'Queens',
#   'cuisine': 'Mexican',
#   'name': 'El Rey Mexican Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fbfa'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Singas Famous Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fbfb'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Pomodoro Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167fbfc'),
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'name': 'Bangkok Grand Palace'},
#  {'_id': ObjectId('67349b13ace753fad167fbfe'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Acappella Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fbff'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167fc00'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "O'Hanlon'S"},
#  {'_id': ObjectId('67349b13ace753fad167fc02'),
#   'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'name': 'Turkish Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167fc03'),
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Barca Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fc04'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Chef'},
#  {'_id': ObjectId('67349b13ace753fad167fc05'),
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'name': 'Olive Garden Italian Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fc08'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Sardis Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fc09'),
#   'borough': 'Manhattan',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Pick-A-Bagel'},
#  {'_id': ObjectId('67349b13ace753fad167fc0a'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Judge Roy Bean'},
#  {'_id': ObjectId('67349b13ace753fad167fc0b'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Pio Pio'},
#  {'_id': ObjectId('67349b13ace753fad167fc0d'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Flagship Diner'},
#  {'_id': ObjectId('67349b13ace753fad167fc0e'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'La Linea Lounge'},
#  {'_id': ObjectId('67349b13ace753fad167fc0f'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Green Trees'},
#  {'_id': ObjectId('67349b13ace753fad167fc10'),
#   'borough': 'Queens',
#   'cuisine': 'Bakery',
#   'name': 'Bagels & Cream Deli'},
#  {'_id': ObjectId('67349b13ace753fad167fc11'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': 'Glory Deli'},
#  {'_id': ObjectId('67349b13ace753fad167fc12'),
#   'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts, Baskin Robbins"},
#  {'_id': ObjectId('67349b13ace753fad167fc13'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Noodle Pudding'},
#  {'_id': ObjectId('67349b13ace753fad167fc14'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': "Michael'S Pastry Shop"},
#  {'_id': ObjectId('67349b13ace753fad167fc15'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fc16'),
#   'borough': 'Manhattan',
#   'cuisine': 'Mediterranean',
#   'name': 'Uncle Nicks'},
#  {'_id': ObjectId('67349b13ace753fad167fc17'),
#   'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167fc18'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'International Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fc1b'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Hangar Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fc1c'),
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fc1d'),
#   'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167fc1e'),
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'name': 'Pieces'},
#  {'_id': ObjectId('67349b13ace753fad167fc1f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Lenny'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fc20'),
#   'borough': 'Manhattan',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fc21'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': "Schick'S Manor"},
#  {'_id': ObjectId('67349b13ace753fad167fc22'),
#   'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'name': 'Tai Pan Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167fc23'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Fifth Ave Cafe /Diner'},
#  {'_id': ObjectId('67349b13ace753fad167fc24'),
#   'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Rolen Bagels'},
#  {'_id': ObjectId('67349b13ace753fad167fc27'),
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'name': 'Cafe Gitane'},
#  {'_id': ObjectId('67349b13ace753fad167fc28'),
#   'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'name': 'Panya/The Barrel'},
#  {'_id': ObjectId('67349b13ace753fad167fc2a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Circle'S Grill"},
#  ...]

# %% [markdown]
# ### 11. Devolver ID del restaurante, el nombre y las calificaciones del restaurante para aquellos restaurantes que obtuvieron una calificación de "A" y obtuvieron un puntaje de 11 en una fecha ISO "2014-08-11T00: 00: 00Z" entre muchas fechas de encuesta

# %%
proyeccion = {"_id":1, "name":1, "grades.score":1}

filtro = {"grades.grade":"A", "grades.score":11, "grades.date": "2014-08-11T00: 00: 00Z"}

list(restaurantes.find(filtro, proyeccion))
# Out:
# []

# %% [markdown]
# ### 12. Devolver ID del restaurante, nombre, dirección y ubicación geográfica del restaurante de aquellos donde el segundo elemento de la matriz coord contiene un valor que es más de 42 y hasta 52

# %%
proyeccion = {"_id":1, "name":1, "address":1, "coord":1}

filtro = {}

list(restaurantes.find(filtro, proyeccion))

# %%
list(restaurantes.find())
# Out:
# [{'_id': ObjectId('67349b13ace753fad167f78b'),
#   'address': {'building': '1007',
#    'coord': [-73.856077, 40.848447],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'_id': ObjectId('67349b13ace753fad167f78c'),
#   'address': {'building': '469',
#    'coord': [-73.961704, 40.662942],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11225'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1404172800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1336435200000}, 'grade': 'A', 'score': 12}],
#   'name': "Wendy'S",
#   'restaurant_id': '30112340'},
#  {'_id': ObjectId('67349b13ace753fad167f78d'),
#   'address': {'building': '351',
#    'coord': [-73.98513559999999, 40.7676919],
#    'street': 'West   57 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1374451200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343692800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1325116800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Dj Reynolds Pub And Restaurant',
#   'restaurant_id': '30191841'},
#  {'_id': ObjectId('67349b13ace753fad167f78e'),
#   'address': {'building': '2780',
#    'coord': [-73.98241999999999, 40.579505],
#    'street': 'Stillwell Avenue',
#    'zipcode': '11224'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1370390400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1318377600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Riviera Caterer',
#   'restaurant_id': '40356018'},
#  {'_id': ObjectId('67349b13ace753fad167f78f'),
#   'address': {'building': '97-22',
#    'coord': [-73.8601152, 40.7311739],
#    'street': '63 Road',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1416787200000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1358380800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1343865600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1323907200000}, 'grade': 'B', 'score': 25}],
#   'name': 'Tov Kosher Kitchen',
#   'restaurant_id': '40356068'},
#  {'_id': ObjectId('67349b13ace753fad167f790'),
#   'address': {'building': '8825',
#    'coord': [-73.8803827, 40.7643124],
#    'street': 'Astoria Boulevard',
#    'zipcode': '11369'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1416009600000}, 'grade': 'Z', 'score': 38},
#    {'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1362182400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1328832000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Brunos On The Boulevard',
#   'restaurant_id': '40356151'},
#  {'_id': ObjectId('67349b13ace753fad167f791'),
#   'address': {'building': '2206',
#    'coord': [-74.1377286, 40.6119572],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1412553600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400544000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1365033600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1327363200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Kosher Island',
#   'restaurant_id': '40356442'},
#  {'_id': ObjectId('67349b13ace753fad167f792'),
#   'address': {'building': '7114',
#    'coord': [-73.9068506, 40.6199034],
#    'street': 'Avenue U',
#    'zipcode': '11234'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1401321600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1375488000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1342569600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1331251200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318550400000}, 'grade': 'A', 'score': 9}],
#   'name': "Wilken'S Fine Food",
#   'restaurant_id': '40356483'},
#  {'_id': ObjectId('67349b13ace753fad167f793'),
#   'address': {'building': '6409',
#    'coord': [-74.00528899999999, 40.628886],
#    'street': '11 Avenue',
#    'zipcode': '11219'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405641600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1375142400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1360713600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1345075200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Regina Caterers',
#   'restaurant_id': '40356649'},
#  {'_id': ObjectId('67349b13ace753fad167f794'),
#   'address': {'building': '1839',
#    'coord': [-73.9482609, 40.6408271],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11226'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1405296000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1373414400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1341964800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1329955200000}, 'grade': 'A', 'score': 8}],
#   'name': 'Taste The Tropics Ice Cream',
#   'restaurant_id': '40356731'},
#  {'_id': ObjectId('67349b13ace753fad167f795'),
#   'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401235200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1339718400000}, 'grade': 'A', 'score': 3}],
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'_id': ObjectId('67349b13ace753fad167f796'),
#   'address': {'building': '7715',
#    'coord': [-73.9973325, 40.61174889999999],
#    'street': '18 Avenue',
#    'zipcode': '11214'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1397606400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1366675200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1335225600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1323993600000}, 'grade': 'A', 'score': 2}],
#   'name': 'C & C Catering Service',
#   'restaurant_id': '40357437'},
#  {'_id': ObjectId('67349b13ace753fad167f797'),
#   'address': {'building': '1269',
#    'coord': [-73.871194, 40.6730975],
#    'street': 'Sutter Avenue',
#    'zipcode': '11208'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1410825600000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1377648000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1364860800000}, 'grade': 'C', 'score': 56},
#    {'date': {'$date': 1344988800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1332892800000}, 'grade': 'B', 'score': 27}],
#   'name': 'May May Kitchen',
#   'restaurant_id': '40358429'},
#  {'_id': ObjectId('67349b13ace753fad167f798'),
#   'address': {'building': '1',
#    'coord': [-73.96926909999999, 40.7685235],
#    'street': 'East   66 Street',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1399420800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1367539200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1324944000000}, 'grade': 'A', 'score': 0}],
#   'name': '1 East 66Th Street Kitchen',
#   'restaurant_id': '40359480'},
#  {'_id': ObjectId('67349b13ace753fad167f799'),
#   'address': {'building': '705',
#    'coord': [-73.9653967, 40.6064339],
#    'street': 'Kings Highway',
#    'zipcode': '11223'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1415577600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1349308800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1337558400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1325203200000}, 'grade': 'B', 'score': 19}],
#   'name': 'Seuda Foods',
#   'restaurant_id': '40360045'},
#  {'_id': ObjectId('67349b13ace753fad167f79a'),
#   'address': {'building': '203',
#    'coord': [-73.97822040000001, 40.6435254],
#    'street': 'Church Avenue',
#    'zipcode': '11218'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1391990400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1357084800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1326067200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1320624000000}, 'grade': 'P', 'score': 12},
#    {'date': {'$date': 1311206400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40360076'},
#  {'_id': ObjectId('67349b13ace753fad167f79b'),
#   'address': {'building': '265-15',
#    'coord': [-73.7032601, 40.7386417],
#    'street': 'Hillside Avenue',
#    'zipcode': '11004'},
#   'borough': 'Queens',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1414454400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40361322'},
#  {'_id': ObjectId('67349b13ace753fad167f79c'),
#   'address': {'building': '6909',
#    'coord': [-74.0259567, 40.6353674],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1408579200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1393977600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1357776000000}, 'grade': 'A', 'score': 10}],
#   'name': 'Nordic Delicacies',
#   'restaurant_id': '40361390'},
#  {'_id': ObjectId('67349b13ace753fad167f79d'),
#   'address': {'building': '522',
#    'coord': [-73.95171, 40.767461],
#    'street': 'East   74 Street',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1409616000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1387411200000}, 'grade': 'B', 'score': 16},
#    {'date': {'$date': 1369699200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1354838400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1332979200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Glorious Food',
#   'restaurant_id': '40361521'},
#  {'_id': ObjectId('67349b13ace753fad167f79e'),
#   'address': {'building': '284',
#    'coord': [-73.9829239, 40.6580753],
#    'street': 'Prospect Park West',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1416355200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1384387200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1354665600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1337212800000}, 'grade': 'A', 'score': 11}],
#   'name': 'The Movable Feast',
#   'restaurant_id': '40361606'},
#  {'_id': ObjectId('67349b13ace753fad167f79f'),
#   'address': {'building': '129-08',
#    'coord': [-73.839297, 40.78147],
#    'street': '20 Avenue',
#    'zipcode': '11356'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1408147200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1377561600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1317254400000}, 'grade': 'A', 'score': 10}],
#   'name': "Sal'S Deli",
#   'restaurant_id': '40361618'},
#  {'_id': ObjectId('67349b13ace753fad167f7a0'),
#   'address': {'building': '759',
#    'coord': [-73.9925306, 40.7309346],
#    'street': 'Broadway',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1390262400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1357257600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1339027200000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 8}],
#   'name': "Bully'S Deli",
#   'restaurant_id': '40361708'},
#  {'_id': ObjectId('67349b13ace753fad167f7a1'),
#   'address': {'building': '3406',
#    'coord': [-73.94024739999999, 40.7623288],
#    'street': '10 Street',
#    'zipcode': '11106'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1395187200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1363132800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1332806400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1301961600000}, 'grade': 'A', 'score': 7}],
#   'name': "Steve Chu'S Deli & Grocery",
#   'restaurant_id': '40361998'},
#  {'_id': ObjectId('67349b13ace753fad167f7a2'),
#   'address': {'building': '502',
#    'coord': [-73.976112, 40.786714],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1393891200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1374105600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1357689600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1334016000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1321315200000}, 'grade': 'A', 'score': 7}],
#   'name': "Harriet'S Kitchen",
#   'restaurant_id': '40362098'},
#  {'_id': ObjectId('67349b13ace753fad167f7a3'),
#   'address': {'building': '730',
#    'coord': [-73.96805719999999, 40.7925587],
#    'street': 'Columbus Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1410480000000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1377648000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1364169600000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1329177600000}, 'grade': 'A', 'score': 12}],
#   'name': 'P & S Deli Grocery',
#   'restaurant_id': '40362264'},
#  {'_id': ObjectId('67349b13ace753fad167f7a4'),
#   'address': {'building': '18',
#    'coord': [-73.996984, 40.72589],
#    'street': 'West Houston Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1365120000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1332288000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1303862400000}, 'grade': 'A', 'score': 5}],
#   'name': 'Angelika Film Center',
#   'restaurant_id': '40362274'},
#  {'_id': ObjectId('67349b13ace753fad167f7a5'),
#   'address': {'building': '531',
#    'coord': [-73.9634876, 40.6940001],
#    'street': 'Myrtle Avenue',
#    'zipcode': '11205'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1395100800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1363564800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1349827200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1316649600000}, 'grade': 'A', 'score': 2}],
#   'name': 'White Castle',
#   'restaurant_id': '40362344'},
#  {'_id': ObjectId('67349b13ace753fad167f7a6'),
#   'address': {'building': '103-05',
#    'coord': [-73.8642349, 40.75356],
#    'street': '37 Avenue',
#    'zipcode': '11368'},
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1398038400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1384214400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1370304000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1352851200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1349913600000}, 'grade': 'P', 'score': 0},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1323302400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1311120000000}, 'grade': 'A', 'score': 11}],
#   'name': 'Ho Mei Restaurant',
#   'restaurant_id': '40362432'},
#  {'_id': ObjectId('67349b13ace753fad167f7a7'),
#   'address': {'building': '60',
#    'coord': [-74.0085357, 40.70620539999999],
#    'street': 'Wall Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'date': {'$date': 1411689600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1348185600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336521600000}, 'grade': 'A', 'score': 11}],
#   'name': 'The Country Cafe',
#   'restaurant_id': '40362715'},
#  {'_id': ObjectId('67349b13ace753fad167f7a8'),
#   'address': {'building': '195',
#    'coord': [-73.9246028, 40.6522396],
#    'street': 'East   56 Street',
#    'zipcode': '11203'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'grades': [{'date': {'$date': 1399939200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1367971200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1348272000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1307318400000}, 'grade': 'A', 'score': 12}],
#   'name': "Shashemene Int'L Restaura",
#   'restaurant_id': '40362869'},
#  {'_id': ObjectId('67349b13ace753fad167f7a9'),
#   'address': {'building': '107',
#    'coord': [-74.00920839999999, 40.7132925],
#    'street': 'Church Street',
#    'zipcode': '10007'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405641600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1393372800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1377475200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1359676800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318896000000}, 'grade': 'A', 'score': 11}],
#   'name': 'Downtown Deli',
#   'restaurant_id': '40363021'},
#  {'_id': ObjectId('67349b13ace753fad167f7aa'),
#   'address': {'building': '1006',
#    'coord': [-73.84856870000002, 40.8903781],
#    'street': 'East 233 Street',
#    'zipcode': '10466'},
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1378339200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1361404800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1341273600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1310342400000}, 'grade': 'A', 'score': 5}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'_id': ObjectId('67349b13ace753fad167f7ab'),
#   'address': {'building': '56',
#    'coord': [-73.991495, 40.692273],
#    'street': 'Court Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1389744000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 10}],
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40363098'},
#  {'_id': ObjectId('67349b13ace753fad167f7ac'),
#   'address': {'building': '7615',
#    'coord': [-74.0228449, 40.6281815],
#    'street': '5 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1417651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1382572800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1366243200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1333584000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Mejlander & Mulgannon',
#   'restaurant_id': '40363117'},
#  {'_id': ObjectId('67349b13ace753fad167f7ad'),
#   'address': {'building': '120',
#    'coord': [-73.9998042, 40.7251256],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1413504000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1324252800000}, 'grade': 'A', 'score': 3}],
#   'name': "Olive'S",
#   'restaurant_id': '40363151'},
#  {'_id': ObjectId('67349b13ace753fad167f7ae'),
#   'address': {'building': '1236',
#    'coord': [-73.8893654, 40.81376179999999],
#    'street': '238 Spofford Ave',
#    'zipcode': '10474'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1388361600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1339459200000}, 'grade': 'B', 'score': 15}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'_id': ObjectId('67349b13ace753fad167f7af'),
#   'address': {'building': '625',
#    'coord': [-73.990494, 40.7569545],
#    'street': '8 Avenue',
#    'zipcode': '10018'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402272000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1389312000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1354838400000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1323734400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1315526400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Cafe Metro',
#   'restaurant_id': '40363298'},
#  {'_id': ObjectId('67349b13ace753fad167f7b0'),
#   'address': {'building': '1069',
#    'coord': [-73.902463, 40.694924],
#    'street': 'Wyckoff Avenue',
#    'zipcode': '11385'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1399507200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1371772800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1356307200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1308096000000}, 'grade': 'A', 'score': 10}],
#   'name': "Tony'S Deli",
#   'restaurant_id': '40363333'},
#  {'_id': ObjectId('67349b13ace753fad167f7b1'),
#   'address': {'building': '405',
#    'coord': [-73.97534999999999, 40.7516269],
#    'street': 'Lexington Avenue',
#    'zipcode': '10174'},
#   'borough': 'Manhattan',
#   'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#   'grades': [{'date': {'$date': 1392940800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1379030400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346112000000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1315872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1304380800000}, 'grade': 'A', 'score': 5}],
#   'name': 'Lexler Deli',
#   'restaurant_id': '40363426'},
#  {'_id': ObjectId('67349b13ace753fad167f7b2'),
#   'address': {'building': '2491',
#    'coord': [-74.1459332, 40.6103714],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1420761600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1386201600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bagels N Buns',
#   'restaurant_id': '40363427'},
#  {'_id': ObjectId('67349b13ace753fad167f7b3'),
#   'address': {'building': '7905',
#    'coord': [-73.8740217, 40.7135015],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'borough': 'Queens',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'date': {'$date': 1410912000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389830400000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1375833600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1361404800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1340150400000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1327968000000}, 'grade': 'B', 'score': 18}],
#   'name': 'Hot Bagels',
#   'restaurant_id': '40363565'},
#  {'_id': ObjectId('67349b13ace753fad167f7b4'),
#   'address': {'building': '87-69',
#    'coord': [-73.8309503, 40.7001121],
#    'street': 'Lefferts Boulevard',
#    'zipcode': '11418'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1393286400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1376438400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1344297600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1332720000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1320364800000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1309305600000}, 'grade': 'A', 'score': 4}],
#   'name': 'Snack Time Grill',
#   'restaurant_id': '40363590'},
#  {'_id': ObjectId('67349b13ace753fad167f7b5'),
#   'address': {'building': '1418',
#    'coord': [-73.95685019999999, 40.7753401],
#    'street': 'Third Avenue',
#    'zipcode': '10028'},
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'date': {'$date': 1401667200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1388102400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1363564800000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1328054400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1309910400000}, 'grade': 'B', 'score': 25}],
#   'name': "Lorenzo & Maria'S",
#   'restaurant_id': '40363630'},
#  {'_id': ObjectId('67349b13ace753fad167f7b6'),
#   'address': {'building': '464',
#    'coord': [-73.9791458, 40.744328],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1407196800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1394064000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1373328000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1359504000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1325721600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1316995200000}, 'grade': 'A', 'score': 0}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363644'},
#  {'_id': ObjectId('67349b13ace753fad167f7b7'),
#   'address': {'building': '437',
#    'coord': [-73.975393, 40.757365],
#    'street': 'Madison Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401753600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370563200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1340928000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1328486400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1308787200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Berkely',
#   'restaurant_id': '40363685'},
#  {'_id': ObjectId('67349b13ace753fad167f7b8'),
#   'address': {'building': '1031',
#    'coord': [-73.9075537, 40.6438684],
#    'street': 'East   92 Street',
#    'zipcode': '11236'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1391558400000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1359417600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1323302400000}, 'grade': 'A', 'score': 10}],
#   'name': "Sonny'S Heros",
#   'restaurant_id': '40363744'},
#  {'_id': ObjectId('67349b13ace753fad167f7b9'),
#   'address': {'building': '1111',
#    'coord': [-74.0796436, 40.59878339999999],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10305'},
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1328140800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363834'},
#  {'_id': ObjectId('67349b13ace753fad167f7ba'),
#   'address': {'building': '976',
#    'coord': [-73.92701509999999, 40.6620192],
#    'street': 'Rutland Road',
#    'zipcode': '11212'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1398211200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1331596800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1321401600000}, 'grade': 'A', 'score': 13}],
#   'name': 'Golden Pavillion',
#   'restaurant_id': '40363920'},
#  {'_id': ObjectId('67349b13ace753fad167f7bb'),
#   'address': {'building': '148',
#    'coord': [-73.9806854, 40.7778589],
#    'street': 'West   72 Street',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1417996800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1399248000000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1365120000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1333065600000}, 'grade': 'A', 'score': 9}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363945'},
#  {'_id': ObjectId('67349b13ace753fad167f7bc'),
#   'address': {'building': '364',
#    'coord': [-73.96084119999999, 40.8014307],
#    'street': 'West  110 Street',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1409788800000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1393372800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1364169600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1329782400000}, 'grade': 'A', 'score': 8}],
#   'name': 'Spoon Bread Catering',
#   'restaurant_id': '40364179'},
#  {'_id': ObjectId('67349b13ace753fad167f7bd'),
#   'address': {'building': '1423',
#    'coord': [-73.9615132, 40.6253268],
#    'street': 'Avenue J',
#    'zipcode': '11230'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1418947200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1386201600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 9}],
#   'name': 'Kosher Bagel Hole',
#   'restaurant_id': '40364220'},
#  {'_id': ObjectId('67349b13ace753fad167f7be'),
#   'address': {'building': '0',
#    'coord': [-84.2040813, 9.9986585],
#    'street': 'Guardia Airport Parking',
#    'zipcode': '11371'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400198400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1337040000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1320192000000}, 'grade': 'C', 'score': 32}],
#   'name': 'Terminal Cafe/Yankee Clipper',
#   'restaurant_id': '40364262'},
#  {'_id': ObjectId('67349b13ace753fad167f7bf'),
#   'address': {'building': '73',
#    'coord': [-74.1178949, 40.5734906],
#    'street': 'New Dorp Plaza',
#    'zipcode': '10306'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1416268800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1383782400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1332201600000}, 'grade': 'A', 'score': 5}],
#   'name': 'Plaza Bagels & Deli',
#   'restaurant_id': '40364286'},
#  {'_id': ObjectId('67349b13ace753fad167f7c0'),
#   'address': {'building': '277',
#    'coord': [-73.8941893, 40.8634684],
#    'street': 'East Kingsbridge Road',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1363651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'_id': ObjectId('67349b13ace753fad167f7c1'),
#   'address': {'building': '203',
#    'coord': [-74.15235919999999, 40.5563756],
#    'street': 'Giffords Lane',
#    'zipcode': '10308'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1420416000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1410393600000}, 'grade': 'C', 'score': 39},
#    {'date': {'$date': 1395273600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1337731200000}, 'grade': 'A', 'score': 10}],
#   'name': 'B & M Hot Bagel & Grocery',
#   'restaurant_id': '40364299'},
#  {'_id': ObjectId('67349b13ace753fad167f7c2'),
#   'address': {'building': '94',
#    'coord': [-74.0061936, 40.7092038],
#    'street': 'Fulton Street',
#    'zipcode': '10038'},
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1420502400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1405382400000}, 'grade': 'C', 'score': 48},
#    {'date': {'$date': 1367452800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1348444800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1334793600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Texas Rotisserie',
#   'restaurant_id': '40364304'},
#  {'_id': ObjectId('67349b13ace753fad167f7c3'),
#   'address': {'building': '10004',
#    'coord': [-74.03400479999999, 40.6127077],
#    'street': '4 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1393286400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1372291200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1354492800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1320796800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Philadelhia Grille Express',
#   'restaurant_id': '40364305'},
#  {'_id': ObjectId('67349b13ace753fad167f7c4'),
#   'address': {'building': '178',
#    'coord': [-73.96252129999999, 40.7098035],
#    'street': 'Broadway',
#    'zipcode': '11211'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'date': {'$date': 1394236800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1380326400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1347235200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1313366400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Peter Luger Steakhouse',
#   'restaurant_id': '40364335'},
#  {'_id': ObjectId('67349b13ace753fad167f7c5'),
#   'address': {'building': '1',
#    'coord': [-73.97166039999999, 40.764832],
#    'street': 'East   60 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1413417600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1364860800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1350604800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1335484800000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1322524800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Metropolitan Club',
#   'restaurant_id': '40364347'},
#  {'_id': ObjectId('67349b13ace753fad167f7c6'),
#   'address': {'building': '837',
#    'coord': [-73.9712, 40.751703],
#    'street': '2 Avenue',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405987200000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1317772800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Palm Restaurant',
#   'restaurant_id': '40364355'},
#  {'_id': ObjectId('67349b13ace753fad167f7c7'),
#   'address': {'building': '21',
#    'coord': [-73.9774394, 40.7604522],
#    'street': 'West   52 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400025600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1376352000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1333497600000}, 'grade': 'A', 'score': 12}],
#   'name': '21 Club',
#   'restaurant_id': '40364362'},
#  {'_id': ObjectId('67349b13ace753fad167f7c8'),
#   'address': {'building': '658',
#    'coord': [-73.81363999999999, 40.82941100000001],
#    'street': 'Clarence Ave',
#    'zipcode': '10465'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1403308800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1341964800000}, 'grade': 'A', 'score': 10}],
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'_id': ObjectId('67349b13ace753fad167f7c9'),
#   'address': {'building': '1028',
#    'coord': [-73.966032, 40.762832],
#    'street': '3 Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1410825600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1393200000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1367539200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1345420800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1329091200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Isle Of Capri Resturant',
#   'restaurant_id': '40364373'},
#  {'_id': ObjectId('67349b13ace753fad167f7ca'),
#   'address': {'building': '45',
#    'coord': [-73.9891878, 40.7375638],
#    'street': 'East   18 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1412726400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1366761600000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1326067200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Old Town Bar & Restaurant',
#   'restaurant_id': '40364389'},
#  {'_id': ObjectId('67349b13ace753fad167f7cb'),
#   'address': {'building': '261',
#    'coord': [-73.94839189999999, 40.7224876],
#    'street': 'Driggs Avenue',
#    'zipcode': '11222'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'grades': [{'date': {'$date': 1401494400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1329436800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1318550400000}, 'grade': 'C', 'score': 54}],
#   'name': 'Polish National Home',
#   'restaurant_id': '40364404'},
#  {'_id': ObjectId('67349b13ace753fad167f7cc'),
#   'address': {'building': '62',
#    'coord': [-74.00310999999999, 40.7348888],
#    'street': 'Charles Street',
#    'zipcode': '10014'},
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1369008000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1326844800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1317600000000}, 'grade': 'A', 'score': 10}],
#   'name': 'Seville Restaurant',
#   'restaurant_id': '40364439'},
#  {'_id': ObjectId('67349b13ace753fad167f7cd'),
#   'address': {'building': '100',
#    'coord': [-74.0010484, 40.71599000000001],
#    'street': 'Centre Street',
#    'zipcode': '10013'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1362700800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1331251200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1301529600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Criminal Court Bldg Cafeteria',
#   'restaurant_id': '40364443'},
#  {'_id': ObjectId('67349b13ace753fad167f7ce'),
#   'address': {'building': '657',
#    'coord': [-73.9056678, 40.7066898],
#    'street': 'Fairview Avenue',
#    'zipcode': '11385'},
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'grades': [{'date': {'$date': 1394841600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1363046400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1342828800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1322179200000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1308700800000}, 'grade': 'B', 'score': 20}],
#   'name': 'Gottscheer Hall',
#   'restaurant_id': '40364449'},
#  {'_id': ObjectId('67349b13ace753fad167f7cf'),
#   'address': {'building': '180',
#    'coord': [-73.9788694, 40.7665961],
#    'street': 'Central Park South',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418601600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1407369600000}, 'grade': 'C', 'score': 40},
#    {'date': {'$date': 1375056000000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1355356800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343606400000}, 'grade': 'C', 'score': 4},
#    {'date': {'$date': 1329350400000}, 'grade': 'A', 'score': 2}],
#   'name': 'Nyac Main Dining Room',
#   'restaurant_id': '40364467'},
#  {'_id': ObjectId('67349b13ace753fad167f7d0'),
#   'address': {'building': '108',
#    'coord': [-73.98146, 40.7250067],
#    'street': 'Avenue B',
#    'zipcode': '10009'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405296000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1388448000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1350864000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1336348800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318550400000}, 'grade': 'A', 'score': 12}],
#   'name': '7B Bar',
#   'restaurant_id': '40364518'},
#  {'_id': ObjectId('67349b13ace753fad167f7d1'),
#   'address': {'building': '96-40',
#    'coord': [-73.86137149999999, 40.7293762],
#    'street': 'Queens Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1394668800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1380499200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1366934400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1347321600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1316390400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1300320000000}, 'grade': 'A', 'score': 12}],
#   'name': 'Ben-Best Deli & Restaurant',
#   'restaurant_id': '40364529'},
#  {'_id': ObjectId('67349b13ace753fad167f7d2'),
#   'address': {'building': '215',
#    'coord': [-73.9805679, 40.7659436],
#    'street': 'West 57 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1411603200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1392336000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1376006400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1361491200000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1329350400000}, 'grade': 'A', 'score': 8}],
#   'name': 'Cafe Atelier (Art Students League)',
#   'restaurant_id': '40364531'},
#  {'_id': ObjectId('67349b13ace753fad167f7d3'),
#   'address': {'building': '845',
#    'coord': [-73.965531, 40.765431],
#    'street': 'Lexington Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1363824000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1350518400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336348800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1305590400000}, 'grade': 'A', 'score': 5}],
#   'name': "Donohue'S Steak House",
#   'restaurant_id': '40364572'},
#  {'_id': ObjectId('67349b13ace753fad167f7d4'),
#   'address': {'building': '311',
#    'coord': [-73.98621899999999, 40.763406],
#    'street': 'West   51 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1415577600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1374019200000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1360108800000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1342396800000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1331164800000}, 'grade': 'C', 'score': 7}],
#   'name': 'Tout Va Bien',
#   'restaurant_id': '40364576'},
#  {'_id': ObjectId('67349b13ace753fad167f7d5'),
#   'address': {'building': '386',
#    'coord': [-73.9818918, 40.6901211],
#    'street': 'Flatbush Avenue Extension',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1415923200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1394409600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1357776000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346716800000}, 'grade': 'A', 'score': 7}],
#   'name': "Junior'S",
#   'restaurant_id': '40364581'},
#  {'_id': ObjectId('67349b13ace753fad167f7d6'),
#   'address': {'building': '37',
#    'coord': [-74.138263, 40.546681],
#    'street': 'Mansion Ave',
#    'zipcode': '10308'},
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1398124800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1339200000000}, 'grade': 'A', 'score': 8}],
#   'name': 'Great Kills Yacht Club',
#   'restaurant_id': '40364610'},
#  {'_id': ObjectId('67349b13ace753fad167f7d7'),
#   'address': {'building': '251',
#    'coord': [-73.9775552, 40.7432016],
#    'street': 'East   31 Street',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1398124800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1371600000000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1337644800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Marchis Restaurant',
#   'restaurant_id': '40364668'},
#  {'_id': ObjectId('67349b13ace753fad167f7d8'),
#   'address': {'building': '2602',
#    'coord': [-73.95443709999999, 40.5877993],
#    'street': 'East   15 Street',
#    'zipcode': '11235'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400025600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1367020800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1353628800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1331683200000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1310601600000}, 'grade': 'B', 'score': 21}],
#   'name': 'Towne Cafe',
#   'restaurant_id': '40364681'},
#  {'_id': ObjectId('67349b13ace753fad167f7d9'),
#   'address': {'building': '.1-A',
#    'coord': [-48.9424, -16.3550032],
#    'street': 'East 77 St',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'date': {'$date': 1416787200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1364947200000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1349136000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1335312000000}, 'grade': 'A', 'score': 8}],
#   'name': 'Dining Room',
#   'restaurant_id': '40364691'},
#  {'_id': ObjectId('67349b13ace753fad167f7da'),
#   'address': {'building': '56',
#    'coord': [-74.004758, 40.741207],
#    'street': '9 Avenue',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370822400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1348617600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1321228800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Old Homestead',
#   'restaurant_id': '40364715'},
#  {'_id': ObjectId('67349b13ace753fad167f7db'),
#   'address': {'building': '156-71',
#    'coord': [-73.840437, 40.6627235],
# ...
#    {'date': {'$date': 1347408000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1316044800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Elmhurst Famous Pizza',
#   'restaurant_id': '40395597'},
#  {'_id': ObjectId('67349b13ace753fad167fb5a'),
#   'address': {'building': '300',
#    'coord': [-73.8787725, 40.8728659],
#    'street': 'East 204 Street',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1391212800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1358208000000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'_id': ObjectId('67349b13ace753fad167fb5b'),
#   'address': {'building': '113335',
#    'coord': [-73.96712, 40.798503],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1399852800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336608000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1325203200000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1312848000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Camilles',
#   'restaurant_id': '40395691'},
#  {'_id': ObjectId('67349b13ace753fad167fb5c'),
#   'address': {'building': '200',
#    'coord': [-73.9875796, 40.7709609],
#    'street': 'West   60 Street',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1406505600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1374796800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1343779200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1333065600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1320796800000}, 'grade': 'A', 'score': 13}],
#   'name': 'Olympic Flame Diner',
#   'restaurant_id': '40395723'},
#  {'_id': ObjectId('67349b13ace753fad167fb5d'),
#   'address': {'building': '357',
#    'coord': [-73.96642899999999, 40.754211],
#    'street': 'East 50 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1382400000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1364947200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343001600000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1318464000000}, 'grade': 'B', 'score': 15}],
#   'name': 'Indigo Indian Cuisine',
#   'restaurant_id': '40395748'},
#  {'_id': ObjectId('67349b13ace753fad167fb5e'),
#   'address': {'building': '150',
#    'coord': [-73.9908184, 40.686652],
#    'street': 'Smith Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1381968000000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1367366400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1353456000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1350604800000}, 'grade': 'P', 'score': 0},
#    {'date': {'$date': 1319500800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1306108800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Caruso Pizzeria & Restaurant',
#   'restaurant_id': '40395774'},
#  {'_id': ObjectId('67349b13ace753fad167fb5f'),
#   'address': {'building': '455',
#    'coord': [-73.98475669999999, 40.6626618],
#    'street': '7 Avenue',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indonesian',
#   'grades': [{'date': {'$date': 1400716800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1367452800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1349222400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1315440000000}, 'grade': 'C', 'score': 29}],
#   'name': 'Java Restaurant',
#   'restaurant_id': '40395826'},
#  {'_id': ObjectId('67349b13ace753fad167fb60'),
#   'address': {'building': '34-37',
#    'coord': [-73.7735119, 40.7693963],
#    'street': 'Bell Boulevard',
#    'zipcode': '11361'},
#   'borough': 'Queens',
#   'cuisine': 'Mexican',
#   'grades': [{'date': {'$date': 1414108800000}, 'grade': 'C', 'score': 52},
#    {'date': {'$date': 1393977600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1373068800000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1354924800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1349222400000}, 'grade': 'P', 'score': 3},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Tequilla Sunrise',
#   'restaurant_id': '40395858'},
#  {'_id': ObjectId('67349b13ace753fad167fb61'),
#   'address': {'building': '411',
#    'coord': [-73.98352299999999, 40.743549],
#    'street': 'Park Avenue South',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1421107200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1408060800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1377734400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1364515200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1330560000000}, 'grade': 'A', 'score': 2}],
#   'name': 'Les Halles',
#   'restaurant_id': '40395860'},
#  {'_id': ObjectId('67349b13ace753fad167fb62'),
#   'address': {'building': '2807',
#    'coord': [-73.94473839999999, 40.6158108],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11229'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1410912000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1395705600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1358899200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1317859200000}, 'grade': 'A', 'score': 10}],
#   'name': 'Pizza Nosh',
#   'restaurant_id': '40395865'},
#  {'_id': ObjectId('67349b13ace753fad167fb63'),
#   'address': {'building': '3533',
#    'coord': [-73.9509786, 40.8264242],
#    'street': 'Broadway',
#    'zipcode': '10031'},
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'date': {'$date': 1412035200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1395014400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1375660800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1346889600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1333411200000}, 'grade': 'B', 'score': 22}],
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40395872'},
#  {'_id': ObjectId('67349b13ace753fad167fb64'),
#   'address': {'building': '98-08',
#    'coord': [-73.84043869999999, 40.6797863],
#    'street': 'Rockaway Boulevard',
#    'zipcode': '11417'},
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1367971200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1335139200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1305504000000}, 'grade': 'A', 'score': 13}],
#   'name': 'White Castle',
#   'restaurant_id': '40395882'},
#  {'_id': ObjectId('67349b13ace753fad167fb65'),
#   'address': {'building': '1454',
#    'coord': [-73.9563642, 40.7712012],
#    'street': '2 Avenue',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418774400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1398729600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1364774400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1350864000000}, 'grade': 'A', 'score': 12}],
#   'name': 'The Stumble Inn',
#   'restaurant_id': '40395892'},
#  {'_id': ObjectId('67349b13ace753fad167fb66'),
#   'address': {'building': '7559',
#    'coord': [-73.8754225, 40.713315],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1419292800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1405555200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1389225600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1367280000000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1347667200000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1333324800000}, 'grade': 'B', 'score': 20}],
#   'name': 'Rosa #2 Pizzeria',
#   'restaurant_id': '40395906'},
#  {'_id': ObjectId('67349b13ace753fad167fb67'),
#   'address': {'building': '250-01',
#    'coord': [-73.737484, 40.7683787],
#    'street': 'Northern Boulevard',
#    'zipcode': '11362'},
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1403136000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1390867200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1375315200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343001600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1313020800000}, 'grade': 'A', 'score': 0}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395910'},
#  {'_id': ObjectId('67349b13ace753fad167fb68'),
#   'address': {'building': '504',
#    'coord': [-73.9194763, 40.807466],
#    'street': 'East  138 Street',
#    'zipcode': '10454'},
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1417132800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1403222400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1387238400000}, 'grade': 'C', 'score': 50},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1337558400000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1325203200000}, 'grade': 'A', 'score': 12}],
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'_id': ObjectId('67349b13ace753fad167fb69'),
#   'address': {'building': '1660',
#    'coord': [-74.162854, 40.60778699999999],
#    'street': 'Richmond Avenue',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1401753600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1369267200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1338854400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1324944000000}, 'grade': 'C', 'score': 52}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395935'},
#  {'_id': ObjectId('67349b13ace753fad167fb6a'),
#   'address': {'building': '2516',
#    'coord': [-73.86709549999999, 40.8640754],
#    'street': 'White Plains Road',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1391644800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1359504000000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1327968000000}, 'grade': 'A', 'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'_id': ObjectId('67349b13ace753fad167fb6b'),
#   'address': {'building': '84',
#    'coord': [-73.9776503, 40.7521147],
#    'street': 'East 42 Street',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'date': {'$date': 1403049600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1383004800000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1367193600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1324252800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1312761600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Hot & Crusty Bakery',
#   'restaurant_id': '40395996'},
#  {'_id': ObjectId('67349b13ace753fad167fb6c'),
#   'address': {'building': '65',
#    'coord': [-73.98606099999999, 40.728176],
#    'street': 'St Marks Place',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1403740800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1378771200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1363910400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1346803200000}, 'grade': 'B', 'score': 20}],
#   'name': 'Jules Bistro',
#   'restaurant_id': '40396000'},
#  {'_id': ObjectId('67349b13ace753fad167fb6d'),
#   'address': {'building': '180',
#    'coord': [-73.98087199999999, 40.775067],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1386374400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1332460800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1305590400000}, 'grade': 'B', 'score': 18}],
#   'name': 'Il Violino',
#   'restaurant_id': '40396019'},
#  {'_id': ObjectId('67349b13ace753fad167fb6e'),
#   'address': {'building': '78',
#    'coord': [-73.9981541, 40.7351897],
#    'street': 'West   11 Street',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1396569600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1345593600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1329782400000}, 'grade': 'A', 'score': 10}],
#   'name': 'French Roast',
#   'restaurant_id': '40396020'},
#  {'_id': ObjectId('67349b13ace753fad167fb6f'),
#   'address': {'building': '532',
#    'coord': [-73.9738917, 40.7605744],
#    'street': 'Madison Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1403740800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1383091200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1370563200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1350345600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1336003200000}, 'grade': 'B', 'score': 16},
#    {'date': {'$date': 1324944000000}, 'grade': 'A', 'score': 5}],
#   'name': "Smiler'S Deli",
#   'restaurant_id': '40396037'},
#  {'_id': ObjectId('67349b13ace753fad167fb70'),
#   'address': {'building': '780',
#    'coord': [-73.8630529, 40.8456372],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1410220800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1374105600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1361750400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346716800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1333929600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1317081600000}, 'grade': 'A', 'score': 2}],
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'_id': ObjectId('67349b13ace753fad167fb71'),
#   'address': {'building': '74',
#    'coord': [-73.9956844, 40.7262603],
#    'street': 'Bleeker Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1396224000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1364428800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1342742400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1328745600000}, 'grade': 'A', 'score': 11}],
#   'name': 'Two Boots To Go-Go',
#   'restaurant_id': '40396066'},
#  {'_id': ObjectId('67349b13ace753fad167fb72'),
#   'address': {'building': '10',
#    'coord': [-73.9815103, 40.7475731],
#    'street': 'Park Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1404777600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1375315200000}, 'grade': 'C', 'score': 9},
#    {'date': {'$date': 1358812800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1337299200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1323820800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1312156800000}, 'grade': 'A', 'score': 8}],
#   'name': "Mendy'S",
#   'restaurant_id': '40396074'},
#  ...]
